# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("heisenberg_data.csv")

# %%
test_df0 = df[df['last_matrix'] == 4]
test_df1 = df[df['last_matrix'] == 1]
test_df2 = df[df['last_matrix'] == 2]
test_df3 = df[df['last_matrix'] == 3]

plt.scatter(x=test_df0['val1'], y=test_df0['val2'], c="red", alpha=0.1)
plt.scatter(x=test_df1['val1'], y=test_df1['val2'], c="green", alpha=0.1)
plt.scatter(x=test_df2['val1'], y=test_df2['val2'], c="blue", alpha=0.1)
plt.scatter(x=test_df3['val1'], y=test_df3['val2'], c="black", alpha=0.1)


# adapted from https://www.geeksforgeeks.org/matplotlib-pyplot-legend-in-python/
plt.legend([4, 1, 2, 3])

plt.show()

# %%
plt.scatter(x=test_df0['val1'], y=test_df0['val2'], c="red", alpha=0.1)
plt.show()

plt.scatter(x=test_df1['val1'], y=test_df1['val2'], c="green", alpha=0.1)
plt.show()

plt.scatter(x=test_df2['val1'], y=test_df2['val2'], c="blue", alpha=0.1)
plt.show()

plt.scatter(x=test_df3['val1'], y=test_df3['val2'], c="black", alpha=0.1)
plt.show()

# %%
plt.scatter(x=test_df0['val2'], y=test_df0['val3'], c="red", alpha=0.1)
plt.scatter(x=test_df1['val2'], y=test_df1['val3'], c="green", alpha=0.1)
plt.scatter(x=test_df2['val2'], y=test_df2['val3'], c="blue", alpha=0.1)
plt.scatter(x=test_df3['val2'], y=test_df3['val3'], c="black", alpha=0.1)


# adapted from https://www.geeksforgeeks.org/matplotlib-pyplot-legend-in-python/
plt.legend([4, 1, 2, 3])

plt.show()

# %%
plt.scatter(x=test_df0['val2'], y=test_df0['val3'], c="red", alpha=0.1)
plt.show()

plt.scatter(x=test_df1['val2'], y=test_df1['val3'], c="green", alpha=0.1)
plt.show()

plt.scatter(x=test_df2['val2'], y=test_df2['val3'], c="blue", alpha=0.1)
plt.show()

plt.scatter(x=test_df3['val2'], y=test_df3['val3'], c="black", alpha=0.1)
plt.show()

# %%
plt.scatter(x=test_df0['val3'], y=test_df0['val1'], c="red", alpha=0.1)
plt.scatter(x=test_df1['val3'], y=test_df1['val1'], c="green", alpha=0.1)
plt.scatter(x=test_df2['val3'], y=test_df2['val1'], c="blue", alpha=0.1)
plt.scatter(x=test_df3['val3'], y=test_df3['val1'], c="black", alpha=0.1)


# adapted from https://www.geeksforgeeks.org/matplotlib-pyplot-legend-in-python/
plt.legend([4, 1, 2, 3])

plt.show()

# %%
plt.scatter(x=test_df0['val3'], y=test_df0['val1'], c="red", alpha=0.1)
plt.show()

plt.scatter(x=test_df1['val3'], y=test_df1['val1'], c="green", alpha=0.1)
plt.show()

plt.scatter(x=test_df2['val3'], y=test_df2['val1'], c="blue", alpha=0.1)
plt.show()

plt.scatter(x=test_df3['val3'], y=test_df3['val1'], c="black", alpha=0.1)
plt.show()

# %%
# try PCA to visualize the data points
# adapted from https://www.geeksforgeeks.org/implementing-pca-in-python-with-scikit-learn/

# %%
# from sklearn.datasets import load_breast_cancer
data=df

# construct a dataframe using pandas
df1=pd.DataFrame(df[['val1', 'val2', 'val3']])
 
# Scale data before applying PCA
scaling=StandardScaler()
 
# Use fit and transform method 
scaling.fit(df1)
Scaled_data=scaling.transform(df1)
 
# Set the n_components=3
principal=PCA(n_components=2)
principal.fit(Scaled_data)
x=principal.transform(Scaled_data)
 
# Check the dimensions of data after PCA
print(x.shape)
# Out:
# (9999, 2)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.scatter(x[:,0],x[:,1],c=data['last_matrix'],cmap='plasma')
plt.xlabel('pc1')
plt.ylabel('pc2')
plt.show()

# %%
aug_df = df
aug_df['pc1'] = x[:,0]
aug_df['pc2'] = x[:,1]

# %%
aug_df

filtered0 = x[]

test_df0 = df[df['last_matrix'] == 4]
test_df1 = df[df['last_matrix'] == 1]
test_df2 = df[df['last_matrix'] == 2]
test_df3 = df[df['last_matrix'] == 3]
# Out:
#       val1  val2  val3  last_matrix       pc1       pc2
# 0       -2     5     0            3  0.339779 -0.282668
# 1        3    -6    -1            4 -0.364293  0.559218
# 2       -1     9    -5            1  0.922065  0.448384
# 3       -1   -20     7            3 -1.373031 -0.959834
# 4       -2    -2     0            4  0.087082 -0.283461
# ...    ...   ...   ...          ...       ...       ...
# 9994    -1     5   -11            1  1.401772  1.150397
# 9995    -7    20    -9            2  2.228423  0.046676
# 9996    -8   -22     6            3 -0.765821 -1.859459
# 9997     3    14    -3            1  0.565733  0.795639
# 9998    -7     9    -3            4  1.207223 -0.657036
#
# [9999 rows x 6 columns]

# %%
aug_df0 = aug_df[aug_df['last_matrix'] == 4]
aug_df1 = aug_df[aug_df['last_matrix'] == 1]
aug_df2 = aug_df[aug_df['last_matrix'] == 2]
aug_df3 = aug_df[aug_df['last_matrix'] == 3]

plt.scatter(aug_df0['pc1'], aug_df0['pc2'], alpha=0.2)
plt.xlabel('pc1')
plt.ylabel('pc2')
plt.show()

plt.scatter(aug_df1['pc1'], aug_df1['pc2'], alpha=0.2)
plt.xlabel('pc1')
plt.ylabel('pc2')
plt.show()

plt.scatter(aug_df2['pc1'], aug_df2['pc2'], alpha=0.2)
plt.xlabel('pc1')
plt.ylabel('pc2')
plt.show()

plt.scatter(aug_df3['pc1'], aug_df3['pc2'], alpha=0.2)
plt.xlabel('pc1')
plt.ylabel('pc2')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10,10))
 
# choose projection 3d for creating a 3d graph
axis = fig.add_subplot(111, projection='3d')
 
# x[:,0]is pc1,x[:,1] is pc2 while x[:,2] is pc3
axis.scatter(aug_df['val1'], aug_df['val2'], aug_df['val3'], c=aug_df['last_matrix'],cmap='plasma', alpha=0.3)
axis.set_xlabel("PC1", fontsize=10)
axis.set_ylabel("PC2", fontsize=10)
axis.set_zlabel("PC3", fontsize=10)
# Out:
# Text(0.5, 0, 'PC3')
