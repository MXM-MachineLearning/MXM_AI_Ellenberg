500], Loss: 1.4873
# total loss: 1.4873394966125488
# Epoch [496/500], Loss: 1.4873
# total loss: 1.4873394966125488
# Epoch [497/500], Loss: 1.4873
# total loss: 1.4873396158218384
# Epoch [498/500], Loss: 1.4873
# total loss: 1.4873396158218384
# Epoch [499/500], Loss: 1.4873
# total loss: 1.4873396158218384
# Epoch [500/500], Loss: 1.4873

# %%
def test_model(trained_model, new_data, expected_result):
    test_input = torch.tensor(new_data, dtype=torch.float32)
    test_output = trained_model(test_input)

    predicted_classes = torch.argmax(test_output, dim=1)

    test_output_compare = torch.tensor(expected_result, dtype=torch.int)

    return float(sum(test_output_compare == predicted_classes)/len(test_input))

# %%
test_df = pd.read_csv("four_directions_test.csv")
just_input_test = df.drop('last_matrix', axis=1)
input_data = np.array(just_input_test.values.tolist())
test_df['last_matrix'] = test_df['last_matrix'] - 1
desired_output = torch.tensor(test_df['last_matrix'].tolist(), dtype=torch.float32).long()

# %%
test_model(trained_model, input_data, desired_output)
# Out:
# C:\Users\16089\AppData\Local\Temp\ipykernel_13576\2118059285.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_output_compare = torch.tensor(expected_result, dtype=torch.int)
# 0.25925925374031067

# %%
T = np.array([[0, 1], [1, 0]])

U = np.array([[1, 0], [-1, 1]])

inverse_U = np.array([[1, 0], [1, 1]])

start_array = np.array([0, 1])

# %%
test_input = np.random.randint(1, 10000, size=(500, 2))
test_output_compare = []

for i in test_input:
    test_output_compare.append([int(i[0] < i[1])])

test_model(trained_model, input_data, desired_output)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\16089\Downloads\MXM\Euclidean Algorithm\Donald\four_step_euclidean\four-step-NN.ipynb Cell 9 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> for i in test_input:
#       <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>     test_output_compare.append([int(i[0] < i[1])])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> test_model(trained_model, input_data[0], desired_output[0])
#
# c:\Users\16089\Downloads\MXM\Euclidean Algorithm\Donald\four_step_euclidean\four-step-NN.ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> def test_model(trained_model, new_data, expected_result):
#       <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     test_input = torch.tensor(new_data, dtype=torch.float32)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     test_output = trained_model(test_input)
#       <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>     # apply the step function with the step at 0.5 to decide whether to predict 1 or 0 for this element
#       <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>     predicted_classes = torch.tensor(test_output + 0.5, dtype=torch.int)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\16089\Downloads\MXM\Euclidean Algorithm\Donald\four_step_euclidean\four-step-NN.ipynb Cell 9 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=29'>30</a> x = self.step6(x)
#      <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=30'>31</a> x = self.step7(x)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=31'>32</a> x = self.step8(x)
#      <a href='vscode-notebook-cell:/c%3A/Users/16089/Downloads/MXM/Euclidean%20Algorithm/Donald/four_step_euclidean/four-step-NN.ipynb#W5sZmlsZQ%3D%3D?line=33'>34</a> return x
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\nn\modules\activation.py:1390, in Softmax.forward(self, input)
#    1389 def forward(self, input: Tensor) -> Tensor:
# -> 1390     return F.softmax(input, self.dim, _stacklevel=5)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\nn\functional.py:1841, in softmax(input, dim, _stacklevel, dtype)
#    1839     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1840 if dtype is None:
# -> 1841     ret = input.softmax(dim)
#    1842 else:
#    1843     ret = input.softmax(dim, dtype=dtype)
#
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got 1)

# %%
# test the neural network with the data points from data.csv
df = pd.read_csv("data.csv")

df_input = np.random.randint(1, 100, size=(len(df), 2))

# %%
for i in range(0, len(df_input)):
    df_input[i][0] = df['val1'][i]
    df_input[i][1] = df['val2'][i]

# %%
df_classificaitons = []
for i in range(0, len(df['last_matrix_was_U'])):
    df_classificaitons.append([1-df["last_matrix_was_U"][i]])

# %%
test_model(trained_model, df_input, df_classificaitons)
# Out:
# C:\Users\16089\AppData\Local\Temp\ipykernel_26304\1059146562.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   predicted_classes = torch.tensor(test_output + 0.5, dtype=torch.int)
# 1.0

# %%
test_input = np.random.randint(1, 10000, size=(1, 2))
update_test_type = torch.tensor(test_input, dtype=torch.float32)
output = trained_model(update_test_type)
predicted_class = int(torch.tensor(output + 0.5, dtype=torch.int))
if predicted_class==1:
    next_point = np.array([test_input[0] @ T])
else: 
    next_point = np.array([test_input[0] @ U])
# Out:
# C:\Users\16089\AppData\Local\Temp\ipykernel_26304\2778666344.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   predicted_class = int(torch.tensor(output + 0.5, dtype=torch.int))

# %%
print(test_input)
print(type(test_input))
print(next_point)
print(type(next_point))
print(predicted_class)
# Out:
# [[5406  186]]
# <class 'numpy.ndarray'>
# [[5220  186]]
# <class 'numpy.ndarray'>
# 0

# %%
next_point[0][0]-test_input[0][0], next_point[0][1]-test_input[0][1]
test_input[0][0]-next_point[0][0], test_input[0][1]-next_point[0][1]
# Out:
# (186, 0)

# %%
# function to plot the first 1000 steps of the Euclidean algorithm on a given point or until we reach the y-axis or x-axis
def plot_to_y_axis(cur_input): 
    for _ in range(1, 1000):
        if min(cur_input @ np.array([1, 0]), cur_input @ np.array([0, 1])) == 0:
            break
        output = trained_model(cur_input)
        predicted_class = int(torch.tensor(output + 0.5, dtype=torch.int))
        if predicted_class==1:
            next_point = np.array([np.array(cur_input)[0] @ T])
        else: 
            next_point = np.array([np.array(cur_input)[0] @ U])

        # plot the direction of steps we took to get to the x-axis
        plt.scatter(x=cur_input[0][0], y=cur_input[0][1])

        plt.scatter(x=next_point[0][0], y=cur_input[0][1])

        plt.arrow(cur_input[0][0], cur_input[0][1], next_point[0][0]-cur_input[0][0], next_point[0][1]-cur_input[0][1], width=70, 
                  length_includes_head=True)
        
        cur_input = torch.tensor(next_point, dtype=torch.float32)
    
    plt.show()

# %%
cur_input = np.random.randint(1, 10000, size=(1, 2))
cur_input = torch.tensor(cur_input, dtype=torch.float32)
plot_to_y_axis(cur_input)
# Out:
# C:\Users\16089\AppData\Local\Temp\ipykernel_26304\3226270405.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   predicted_class = int(torch.tensor(output + 0.5, dtype=torch.int))
