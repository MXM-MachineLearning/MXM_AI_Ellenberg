# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

# %%
# code adapted from ChatGPT

# Define your neural network model
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.fc = nn.Linear(2, 1, bias=False)  # Input size 2, output size 1
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):

        # RUN IT ON A GPU if it exists
        if torch.cuda.is_available():
            x = x.to("cuda")

        x = self.fc(x)
        x = self.sigmoid(x)
        
        return x

def train_model(inputs, desired_outputs, num_epochs=100, learning_rate=0.02, momentum=0.9):
    # Convert inputs and desired_outputs to PyTorch tensors
    inputs = torch.tensor(inputs, dtype=torch.float32)
    desired_outputs = torch.tensor(desired_outputs, dtype=torch.float32)
    
    # Create a DataLoader to handle batching (if needed)
    dataset = TensorDataset(inputs, desired_outputs)
    dataloader = DataLoader(dataset, batch_size=1000, shuffle=True)  # Adjust batch_size as needed
    
    # Initialize the model
    model = SimpleModel()
    
    # Define loss function and optimizer
    criterion = nn.MSELoss()  # Mean Squared Error loss
    optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum)
    
    # Training loop
    for epoch in range(num_epochs):
        total_loss = 0.0
        for batch_inputs, batch_desired_outputs in dataloader:
            optimizer.zero_grad()  # Zero the gradients
            outputs = model(batch_inputs)  # Forward pass
            loss = criterion(outputs, batch_desired_outputs)  # Compute the loss
            loss.backward()  # Backpropagation
            optimizer.step()  # Update the model's parameters
            cur_item = loss.item()
            total_loss += cur_item
            # print(cur_item)
        
        # Print the average loss for this epoch
        print(f"total loss: {total_loss}")
        average_loss = total_loss / len(dataloader)
        for i, param in model.named_parameters():
            print(param)
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {average_loss:.4f}')
    
    # Return the trained model
    return model

# %%
input_data = np.random.randint(1, 100, size=(1000, 2))
desired_output = []

for i in input_data:
    desired_output.append([int(i[0] >= i[1])])
    
# Train the model
trained_model = train_model(input_data, desired_output, 500)
# Out:
# total loss: 0.06897056102752686
# Parameter containing:
# tensor([[ 0.5231, -0.4794]], requires_grad=True)
# Epoch [1/500], Loss: 0.0690
# total loss: 0.029300354421138763
# Parameter containing:
# tensor([[ 0.4892, -0.5173]], requires_grad=True)
# Epoch [2/500], Loss: 0.0293
# total loss: 0.019920913502573967
# Parameter containing:
# tensor([[ 0.4731, -0.5376]], requires_grad=True)
# Epoch [3/500], Loss: 0.0199
# total loss: 0.048463501036167145
# Parameter containing:
# tensor([[ 0.4747, -0.5413]], requires_grad=True)
# Epoch [4/500], Loss: 0.0485
# total loss: 0.04978193715214729
# Parameter containing:
# tensor([[ 0.4921, -0.5302]], requires_grad=True)
# Epoch [5/500], Loss: 0.0498
# total loss: 0.026991553604602814
# Parameter containing:
# tensor([[ 0.5236, -0.5053]], requires_grad=True)
# Epoch [6/500], Loss: 0.0270
# total loss: 0.010762839578092098
# Parameter containing:
# tensor([[ 0.5427, -0.4926]], requires_grad=True)
# Epoch [7/500], Loss: 0.0108
# total loss: 0.033781908452510834
# Parameter containing:
# tensor([[ 0.5429, -0.4996]], requires_grad=True)
# Epoch [8/500], Loss: 0.0338
# total loss: 0.027690954506397247
# Parameter containing:
# tensor([[ 0.5269, -0.5233]], requires_grad=True)
# Epoch [9/500], Loss: 0.0277
# total loss: 0.006559304893016815
# Parameter containing:
# tensor([[ 0.5117, -0.5456]], requires_grad=True)
# Epoch [10/500], Loss: 0.0066
# total loss: 0.023086827248334885
# Parameter containing:
# tensor([[ 0.5128, -0.5517]], requires_grad=True)
# Epoch [11/500], Loss: 0.0231
# total loss: 0.0265788696706295
# Parameter containing:
# tensor([[ 0.5292, -0.5427]], requires_grad=True)
# Epoch [12/500], Loss: 0.0266
# total loss: 0.010250325314700603
# Parameter containing:
# tensor([[ 0.5534, -0.5255]], requires_grad=True)
# Epoch [13/500], Loss: 0.0103
# total loss: 0.015474164858460426
# Parameter containing:
# tensor([[ 0.5629, -0.5230]], requires_grad=True)
# Epoch [14/500], Loss: 0.0155
# total loss: 0.023827720433473587
# Parameter containing:
# tensor([[ 0.5564, -0.5367]], requires_grad=True)
# Epoch [15/500], Loss: 0.0238
# total loss: 0.010644313879311085
# Parameter containing:
# tensor([[ 0.5413, -0.5588]], requires_grad=True)
# Epoch [16/500], Loss: 0.0106
# total loss: 0.012034252285957336
# Parameter containing:
# tensor([[ 0.5385, -0.5682]], requires_grad=True)
# Epoch [17/500], Loss: 0.0120
# total loss: 0.01932128518819809
# Parameter containing:
# tensor([[ 0.5496, -0.5638]], requires_grad=True)
# Epoch [18/500], Loss: 0.0193
# total loss: 0.010229014791548252
# Parameter containing:
# tensor([[ 0.5690, -0.5506]], requires_grad=True)
# Epoch [19/500], Loss: 0.0102
# total loss: 0.009810050018131733
# Parameter containing:
# tensor([[ 0.5780, -0.5477]], requires_grad=True)
# Epoch [20/500], Loss: 0.0098
# total loss: 0.016216091811656952
# Parameter containing:
# tensor([[ 0.5737, -0.5581]], requires_grad=True)
# Epoch [21/500], Loss: 0.0162
# total loss: 0.008562222123146057
# Parameter containing:
# tensor([[ 0.5626, -0.5750]], requires_grad=True)
# Epoch [22/500], Loss: 0.0086
# total loss: 0.009251473471522331
# Parameter containing:
# tensor([[ 0.5612, -0.5820]], requires_grad=True)
# Epoch [23/500], Loss: 0.0093
# total loss: 0.013379613868892193
# Parameter containing:
# tensor([[ 0.5714, -0.5772]], requires_grad=True)
# Epoch [24/500], Loss: 0.0134
# total loss: 0.006966878194361925
# Parameter containing:
# tensor([[ 0.5856, -0.5681]], requires_grad=True)
# Epoch [25/500], Loss: 0.0070
# total loss: 0.009140522219240665
# Parameter containing:
# tensor([[ 0.5906, -0.5681]], requires_grad=True)
# Epoch [26/500], Loss: 0.0091
# total loss: 0.011330789886415005
# Parameter containing:
# tensor([[ 0.5854, -0.5782]], requires_grad=True)
# Epoch [27/500], Loss: 0.0113
# total loss: 0.006176538299769163
# Parameter containing:
# tensor([[ 0.5780, -0.5903]], requires_grad=True)
# Epoch [28/500], Loss: 0.0062
# total loss: 0.008980652317404747
# Parameter containing:
# tensor([[ 0.5796, -0.5931]], requires_grad=True)
# Epoch [29/500], Loss: 0.0090
# total loss: 0.009437317959964275
# Parameter containing:
# tensor([[ 0.5899, -0.5871]], requires_grad=True)
# Epoch [30/500], Loss: 0.0094
# total loss: 0.0057725147344172
# Parameter containing:
# tensor([[ 0.5991, -0.5821]], requires_grad=True)
# Epoch [31/500], Loss: 0.0058
# total loss: 0.008679523132741451
# Parameter containing:
# tensor([[ 0.5999, -0.5853]], requires_grad=True)
# Epoch [32/500], Loss: 0.0087
# total loss: 0.00779937207698822
# Parameter containing:
# tensor([[ 0.5943, -0.5949]], requires_grad=True)
# Epoch [33/500], Loss: 0.0078
# total loss: 0.005850972142070532
# Parameter containing:
# tensor([[ 0.5911, -0.6017]], requires_grad=True)
# Epoch [34/500], Loss: 0.0059
# total loss: 0.008166800253093243
# Parameter containing:
# tensor([[ 0.5957, -0.6008]], requires_grad=True)
# Epoch [35/500], Loss: 0.0082
# total loss: 0.006508295889943838
# Parameter containing:
# tensor([[ 0.6044, -0.5956]], requires_grad=True)
# Epoch [36/500], Loss: 0.0065
# total loss: 0.006218535825610161
# Parameter containing:
# tensor([[ 0.6087, -0.5946]], requires_grad=True)
# Epoch [37/500], Loss: 0.0062
# total loss: 0.007499340455979109
# Parameter containing:
# tensor([[ 0.6066, -0.6001]], requires_grad=True)
# Epoch [38/500], Loss: 0.0075
# total loss: 0.005848118104040623
# Parameter containing:
# tensor([[ 0.6025, -0.6074]], requires_grad=True)
# Epoch [39/500], Loss: 0.0058
# total loss: 0.006408096756786108
# Parameter containing:
# tensor([[ 0.6032, -0.6098]], requires_grad=True)
# Epoch [40/500], Loss: 0.0064
# total loss: 0.006789666600525379
# Parameter containing:
# tensor([[ 0.6091, -0.6068]], requires_grad=True)
# Epoch [41/500], Loss: 0.0068
# total loss: 0.005572554189711809
# Parameter containing:
# tensor([[ 0.6147, -0.6041]], requires_grad=True)
# Epoch [42/500], Loss: 0.0056
# total loss: 0.006465007085353136
# Parameter containing:
# tensor([[ 0.6155, -0.6063]], requires_grad=True)
# Epoch [43/500], Loss: 0.0065
# total loss: 0.006166965235024691
# Parameter containing:
# tensor([[ 0.6125, -0.6120]], requires_grad=True)
# Epoch [44/500], Loss: 0.0062
# total loss: 0.005588146857917309
# Parameter containing:
# tensor([[ 0.6112, -0.6160]], requires_grad=True)
# Epoch [45/500], Loss: 0.0056
# total loss: 0.0063161831349134445
# Parameter containing:
# tensor([[ 0.6143, -0.6156]], requires_grad=True)
# Epoch [46/500], Loss: 0.0063
# total loss: 0.005718586966395378
# Parameter containing:
# tensor([[ 0.6194, -0.6130]], requires_grad=True)
# Epoch [47/500], Loss: 0.0057
# total loss: 0.0057002888061106205
# Parameter containing:
# tensor([[ 0.6220, -0.6130]], requires_grad=True)
# Epoch [48/500], Loss: 0.0057
# total loss: 0.006057967431843281
# Parameter containing:
# tensor([[ 0.6208, -0.6166]], requires_grad=True)
# Epoch [49/500], Loss: 0.0061
# total loss: 0.005506336223334074
# Parameter containing:
# tensor([[ 0.6190, -0.6209]], requires_grad=True)
# Epoch [50/500], Loss: 0.0055
# total loss: 0.005748195573687553
# Parameter containing:
# tensor([[ 0.6200, -0.6223]], requires_grad=True)
# Epoch [51/500], Loss: 0.0057
# total loss: 0.005788752809166908
# Parameter containing:
# tensor([[ 0.6238, -0.6208]], requires_grad=True)
# Epoch [52/500], Loss: 0.0058
# total loss: 0.005434720776975155
# Parameter containing:
# tensor([[ 0.6271, -0.6198]], requires_grad=True)
# Epoch [53/500], Loss: 0.0054
# total loss: 0.005728982854634523
# Parameter containing:
# tensor([[ 0.6276, -0.6216]], requires_grad=True)
# Epoch [54/500], Loss: 0.0057
# total loss: 0.005572783760726452
# Parameter containing:
# tensor([[ 0.6262, -0.6252]], requires_grad=True)
# Epoch [55/500], Loss: 0.0056
# total loss: 0.0054359957575798035
# Parameter containing:
# tensor([[ 0.6260, -0.6276]], requires_grad=True)
# Epoch [56/500], Loss: 0.0054
# total loss: 0.005645879544317722
# Parameter containing:
# tensor([[ 0.6283, -0.6275]], requires_grad=True)
# Epoch [57/500], Loss: 0.0056
# total loss: 0.005428902804851532
# Parameter containing:
# tensor([[ 0.6315, -0.6264]], requires_grad=True)
# Epoch [58/500], Loss: 0.0054
# total loss: 0.0054518915712833405
# Parameter containing:
# tensor([[ 0.6331, -0.6269]], requires_grad=True)
# Epoch [59/500], Loss: 0.0055
# total loss: 0.005535735283046961
# Parameter containing:
# tensor([[ 0.6327, -0.6294]], requires_grad=True)
# Epoch [60/500], Loss: 0.0055
# total loss: 0.005357082933187485
# Parameter containing:
# tensor([[ 0.6321, -0.6321]], requires_grad=True)
# Epoch [61/500], Loss: 0.0054
# total loss: 0.005443898495286703
# Parameter containing:
# tensor([[ 0.6331, -0.6331]], requires_grad=True)
# Epoch [62/500], Loss: 0.0054
# total loss: 0.005431525409221649
# Parameter containing:
# tensor([[ 0.6356, -0.6326]], requires_grad=True)
# Epoch [63/500], Loss: 0.0054
# total loss: 0.005325197242200375
# Parameter containing:
# tensor([[ 0.6378, -0.6325]], requires_grad=True)
# Epoch [64/500], Loss: 0.0053
# total loss: 0.005413454957306385
# Parameter containing:
# tensor([[ 0.6384, -0.6339]], requires_grad=True)
# Epoch [65/500], Loss: 0.0054
# total loss: 0.005349879618734121
# Parameter containing:
# tensor([[ 0.6380, -0.6363]], requires_grad=True)
# Epoch [66/500], Loss: 0.0053
# total loss: 0.005309953819960356
# Parameter containing:
# tensor([[ 0.6382, -0.6379]], requires_grad=True)
# Epoch [67/500], Loss: 0.0053
# total loss: 0.005367011297494173
# Parameter containing:
# tensor([[ 0.6399, -0.6382]], requires_grad=True)
# Epoch [68/500], Loss: 0.0054
# total loss: 0.005292151588946581
# Parameter containing:
# tensor([[ 0.6421, -0.6380]], requires_grad=True)
# Epoch [69/500], Loss: 0.0053
# total loss: 0.005296440329402685
# Parameter containing:
# tensor([[ 0.6433, -0.6386]], requires_grad=True)
# Epoch [70/500], Loss: 0.0053
# total loss: 0.005315572954714298
# Parameter containing:
# tensor([[ 0.6434, -0.6404]], requires_grad=True)
# Epoch [71/500], Loss: 0.0053
# total loss: 0.00525475712493062
# Parameter containing:
# tensor([[ 0.6435, -0.6423]], requires_grad=True)
# Epoch [72/500], Loss: 0.0053
# total loss: 0.00527635682374239
# Parameter containing:
# tensor([[ 0.6444, -0.6432]], requires_grad=True)
# Epoch [73/500], Loss: 0.0053
# total loss: 0.005267644766718149
# Parameter containing:
# tensor([[ 0.6462, -0.6433]], requires_grad=True)
# Epoch [74/500], Loss: 0.0053
# total loss: 0.005228647030889988
# Parameter containing:
# tensor([[ 0.6478, -0.6436]], requires_grad=True)
# Epoch [75/500], Loss: 0.0052
# total loss: 0.005250377580523491
# Parameter containing:
# tensor([[ 0.6485, -0.6447]], requires_grad=True)
# Epoch [76/500], Loss: 0.0053
# total loss: 0.0052269380539655685
# Parameter containing:
# tensor([[ 0.6486, -0.6464]], requires_grad=True)
# Epoch [77/500], Loss: 0.0052
# total loss: 0.0052073984406888485
# Parameter containing:
# tensor([[ 0.6491, -0.6478]], requires_grad=True)
# Epoch [78/500], Loss: 0.0052
# total loss: 0.0052206008695065975
# Parameter containing:
# tensor([[ 0.6504, -0.6483]], requires_grad=True)
# Epoch [79/500], Loss: 0.0052
# total loss: 0.0051934425719082355
# Parameter containing:
# tensor([[ 0.6520, -0.6485]], requires_grad=True)
# Epoch [80/500], Loss: 0.0052
# total loss: 0.005187049973756075
# Parameter containing:
# tensor([[ 0.6531, -0.6492]], requires_grad=True)
# Epoch [81/500], Loss: 0.0052
# total loss: 0.005189881194382906
# Parameter containing:
# tensor([[ 0.6536, -0.6505]], requires_grad=True)
# Epoch [82/500], Loss: 0.0052
# total loss: 0.005165863782167435
# Parameter containing:
# tensor([[ 0.6539, -0.6520]], requires_grad=True)
# Epoch [83/500], Loss: 0.0052
# total loss: 0.005165552254766226
# Parameter containing:
# tensor([[ 0.6548, -0.6529]], requires_grad=True)
# Epoch [84/500], Loss: 0.0052
# total loss: 0.005160299129784107
# Parameter containing:
# tensor([[ 0.6561, -0.6534]], requires_grad=True)
# Epoch [85/500], Loss: 0.0052
# total loss: 0.0051419115625321865
# Parameter containing:
# tensor([[ 0.6574, -0.6538]], requires_grad=True)
# Epoch [86/500], Loss: 0.0051
# total loss: 0.00514287268742919
# Parameter containing:
# tensor([[ 0.6582, -0.6548]], requires_grad=True)
# Epoch [87/500], Loss: 0.0051
# total loss: 0.005132788326591253
# Parameter containing:
# tensor([[ 0.6587, -0.6561]], requires_grad=True)
# Epoch [88/500], Loss: 0.0051
# total loss: 0.0051199025474488735
# Parameter containing:
# tensor([[ 0.6593, -0.6572]], requires_grad=True)
# Epoch [89/500], Loss: 0.0051
# total loss: 0.0051194182597100735
# Parameter containing:
# tensor([[ 0.6603, -0.6580]], requires_grad=True)
# Epoch [90/500], Loss: 0.0051
# total loss: 0.0051074521616101265
# Parameter containing:
# tensor([[ 0.6615, -0.6585]], requires_grad=True)
# Epoch [91/500], Loss: 0.0051
# total loss: 0.005098697263747454
# Parameter containing:
# tensor([[ 0.6626, -0.6591]], requires_grad=True)
# Epoch [92/500], Loss: 0.0051
# total loss: 0.00509584229439497
# Parameter containing:
# tensor([[ 0.6632, -0.6602]], requires_grad=True)
# Epoch [93/500], Loss: 0.0051
# total loss: 0.005083998665213585
# Parameter containing:
# tensor([[ 0.6638, -0.6614]], requires_grad=True)
# Epoch [94/500], Loss: 0.0051
# total loss: 0.005077676847577095
# Parameter containing:
# tensor([[ 0.6645, -0.6623]], requires_grad=True)
# Epoch [95/500], Loss: 0.0051
# total loss: 0.0050726537592709064
# Parameter containing:
# tensor([[ 0.6656, -0.6629]], requires_grad=True)
# Epoch [96/500], Loss: 0.0051
# total loss: 0.005061905365437269
# Parameter containing:
# tensor([[ 0.6667, -0.6635]], requires_grad=True)
# Epoch [97/500], Loss: 0.0051
# total loss: 0.0050566853024065495
# Parameter containing:
# tensor([[ 0.6676, -0.6644]], requires_grad=True)
# Epoch [98/500], Loss: 0.0051
# total loss: 0.005050118081271648
# Parameter containing:
# tensor([[ 0.6682, -0.6654]], requires_grad=True)
# Epoch [99/500], Loss: 0.0051
# total loss: 0.005040750838816166
# Parameter containing:
# tensor([[ 0.6689, -0.6665]], requires_grad=True)
# Epoch [100/500], Loss: 0.0050
# total loss: 0.005035738926380873
# Parameter containing:
# tensor([[ 0.6698, -0.6673]], requires_grad=True)
# Epoch [101/500], Loss: 0.0050
# total loss: 0.005028324667364359
# Parameter containing:
# tensor([[ 0.6708, -0.6679]], requires_grad=True)
# Epoch [102/500], Loss: 0.0050
# total loss: 0.005020194686949253
# Parameter containing:
# tensor([[ 0.6718, -0.6686]], requires_grad=True)
# Epoch [103/500], Loss: 0.0050
# total loss: 0.005014942027628422
# Parameter containing:
# tensor([[ 0.6725, -0.6695]], requires_grad=True)
# Epoch [104/500], Loss: 0.0050
# total loss: 0.005007241386920214
# Parameter containing:
# tensor([[ 0.6732, -0.6705]], requires_grad=True)
# Epoch [105/500], Loss: 0.0050
# total loss: 0.00500003807246685
# Parameter containing:
# tensor([[ 0.6739, -0.6714]], requires_grad=True)
# Epoch [106/500], Loss: 0.0050
# total loss: 0.004994396585971117
# Parameter containing:
# tensor([[ 0.6748, -0.6722]], requires_grad=True)
# Epoch [107/500], Loss: 0.0050
# total loss: 0.004986768588423729
# Parameter containing:
# tensor([[ 0.6758, -0.6728]], requires_grad=True)
# Epoch [108/500], Loss: 0.0050
# total loss: 0.004980173893272877
# Parameter containing:
# tensor([[ 0.6767, -0.6736]], requires_grad=True)
# Epoch [109/500], Loss: 0.0050
# total loss: 0.004974180832505226
# Parameter containing:
# tensor([[ 0.6774, -0.6745]], requires_grad=True)
# Epoch [110/500], Loss: 0.0050
# total loss: 0.004966815933585167
# Parameter containing:
# tensor([[ 0.6781, -0.6755]], requires_grad=True)
# Epoch [111/500], Loss: 0.0050
# total loss: 0.004960568621754646
# Parameter containing:
# tensor([[ 0.6789, -0.6763]], requires_grad=True)
# Epoch [112/500], Loss: 0.0050
# total loss: 0.00495432922616601
# Parameter containing:
# tensor([[ 0.6798, -0.6770]], requires_grad=True)
# Epoch [113/500], Loss: 0.0050
# total loss: 0.004947283770889044
# Parameter containing:
# tensor([[ 0.6807, -0.6777]], requires_grad=True)
# Epoch [114/500], Loss: 0.0049
# total loss: 0.004941209219396114
# Parameter containing:
# tensor([[ 0.6816, -0.6785]], requires_grad=True)
# Epoch [115/500], Loss: 0.0049
# total loss: 0.004934844095259905
# Parameter containing:
# tensor([[ 0.6823, -0.6794]], requires_grad=True)
# Epoch [116/500], Loss: 0.0049
# total loss: 0.004928110633045435
# Parameter containing:
# tensor([[ 0.6830, -0.6803]], requires_grad=True)
# Epoch [117/500], Loss: 0.0049
# total loss: 0.004922107327729464
# Parameter containing:
# tensor([[ 0.6838, -0.6811]], requires_grad=True)
# Epoch [118/500], Loss: 0.0049
# total loss: 0.004915718454867601
# Parameter containing:
# tensor([[ 0.6847, -0.6818]], requires_grad=True)
# Epoch [119/500], Loss: 0.0049
# total loss: 0.004909248556941748
# Parameter containing:
# tensor([[ 0.6856, -0.6826]], requires_grad=True)
# Epoch [120/500], Loss: 0.0049
# total loss: 0.00490327225998044
# Parameter containing:
# tensor([[ 0.6863, -0.6834]], requires_grad=True)
# Epoch [121/500], Loss: 0.0049
# total loss: 0.004896927624940872
# Parameter containing:
# tensor([[ 0.6871, -0.6842]], requires_grad=True)
# Epoch [122/500], Loss: 0.0049
# total loss: 0.004890670068562031
# Parameter containing:
# tensor([[ 0.6878, -0.6851]], requires_grad=True)
# Epoch [123/500], Loss: 0.0049
# total loss: 0.00488470820710063
# Parameter containing:
# tensor([[ 0.6886, -0.6858]], requires_grad=True)
# Epoch [124/500], Loss: 0.0049
# total loss: 0.004878453444689512
# Parameter containing:
# tensor([[ 0.6895, -0.6866]], requires_grad=True)
# Epoch [125/500], Loss: 0.0049
# total loss: 0.004872357007116079
# Parameter containing:
# tensor([[ 0.6903, -0.6873]], requires_grad=True)
# Epoch [126/500], Loss: 0.0049
# total loss: 0.004866419360041618
# Parameter containing:
# tensor([[ 0.6911, -0.6881]], requires_grad=True)
# Epoch [127/500], Loss: 0.0049
# total loss: 0.004860271699726582
# Parameter containing:
# tensor([[ 0.6918, -0.6890]], requires_grad=True)
# Epoch [128/500], Loss: 0.0049
# total loss: 0.00485430471599102
# Parameter containing:
# tensor([[ 0.6926, -0.6898]], requires_grad=True)
# Epoch [129/500], Loss: 0.0049
# total loss: 0.0048483991995453835
# Parameter containing:
# tensor([[ 0.6934, -0.6905]], requires_grad=True)
# Epoch [130/500], Loss: 0.0048
# total loss: 0.004842367023229599
# Parameter containing:
# tensor([[ 0.6942, -0.6912]], requires_grad=True)
# Epoch [131/500], Loss: 0.0048
# total loss: 0.004836497362703085
# Parameter containing:
# tensor([[ 0.6950, -0.6920]], requires_grad=True)
# Epoch [132/500], Loss: 0.0048
# total loss: 0.004830644465982914
# Parameter containing:
# tensor([[ 0.6957, -0.6928]], requires_grad=True)
# Epoch [133/500], Loss: 0.0048
# total loss: 0.004824723582714796
# Parameter containing:
# tensor([[ 0.6965, -0.6936]], requires_grad=True)
# Epoch [134/500], Loss: 0.0048
# total loss: 0.004818939138203859
# Parameter containing:
# tensor([[ 0.6972, -0.6944]], requires_grad=True)
# Epoch [135/500], Loss: 0.0048
# total loss: 0.0048131453804671764
# Parameter containing:
# tensor([[ 0.6980, -0.6951]], requires_grad=True)
# Epoch [136/500], Loss: 0.0048
# total loss: 0.00480732973664999
# Parameter containing:
# tensor([[ 0.6988, -0.6959]], requires_grad=True)
# Epoch [137/500], Loss: 0.0048
# total loss: 0.004801622591912746
# Parameter containing:
# tensor([[ 0.6996, -0.6966]], requires_grad=True)
# Epoch [138/500], Loss: 0.0048
# total loss: 0.004795895889401436
# Parameter containing:
# tensor([[ 0.7003, -0.6974]], requires_grad=True)
# Epoch [139/500], Loss: 0.0048
# total loss: 0.004790178500115871
# Parameter containing:
# tensor([[ 0.7011, -0.6982]], requires_grad=True)
# Epoch [140/500], Loss: 0.0048
# total loss: 0.004784542601555586
# Parameter containing:
# tensor([[ 0.7018, -0.6989]], requires_grad=True)
# Epoch [141/500], Loss: 0.0048
# total loss: 0.004778890870511532
# Parameter containing:
# tensor([[ 0.7026, -0.6997]], requires_grad=True)
# Epoch [142/500], Loss: 0.0048
# total loss: 0.004773261956870556
# Parameter containing:
# tensor([[ 0.7034, -0.7004]], requires_grad=True)
# Epoch [143/500], Loss: 0.0048
# total loss: 0.0047676945105195045
# Parameter containing:
# tensor([[ 0.7041, -0.7012]], requires_grad=True)
# Epoch [144/500], Loss: 0.0048
# total loss: 0.004762117750942707
# Parameter containing:
# tensor([[ 0.7049, -0.7019]], requires_grad=True)
# Epoch [145/500], Loss: 0.0048
# total loss: 0.004756570793688297
# Parameter containing:
# tensor([[ 0.7056, -0.7027]], requires_grad=True)
# Epoch [146/500], Loss: 0.0048
# total loss: 0.004751073662191629
# Parameter containing:
# tensor([[ 0.7064, -0.7034]], requires_grad=True)
# Epoch [147/500], Loss: 0.0048
# total loss: 0.004745570942759514
# Parameter containing:
# tensor([[ 0.7071, -0.7042]], requires_grad=True)
# Epoch [148/500], Loss: 0.0047
# total loss: 0.004740105476230383
# Parameter containing:
# tensor([[ 0.7079, -0.7049]], requires_grad=True)
# Epoch [149/500], Loss: 0.0047
# total loss: 0.004734674468636513
# Parameter containing:
# tensor([[ 0.7086, -0.7057]], requires_grad=True)
# Epoch [150/500], Loss: 0.0047
# total loss: 0.004729247186332941
# Parameter containing:
# tensor([[ 0.7094, -0.7064]], requires_grad=True)
# Epoch [151/500], Loss: 0.0047
# total loss: 0.0047238548286259174
# Parameter containing:
# tensor([[ 0.7101, -0.7072]], requires_grad=True)
# Epoch [152/500], Loss: 0.0047
# total loss: 0.00471849087625742
# Parameter containing:
# tensor([[ 0.7108, -0.7079]], requires_grad=True)
# Epoch [153/500], Loss: 0.0047
# total loss: 0.004713138565421104
# Parameter containing:
# tensor([[ 0.7116, -0.7086]], requires_grad=True)
# Epoch [154/500], Loss: 0.0047
# total loss: 0.004707816522568464
# Parameter containing:
# tensor([[ 0.7123, -0.7093]], requires_grad=True)
# Epoch [155/500], Loss: 0.0047
# total loss: 0.004702521953731775
# Parameter containing:
# tensor([[ 0.7131, -0.7101]], requires_grad=True)
# Epoch [156/500], Loss: 0.0047
# total loss: 0.004697238560765982
# Parameter containing:
# tensor([[ 0.7138, -0.7108]], requires_grad=True)
# Epoch [157/500], Loss: 0.0047
# total loss: 0.004691986832767725
# Parameter containing:
# tensor([[ 0.7145, -0.7116]], requires_grad=True)
# Epoch [158/500], Loss: 0.0047
# total loss: 0.004686759784817696
# Parameter containing:
# tensor([[ 0.7153, -0.7123]], requires_grad=True)
# Epoch [159/500], Loss: 0.0047
# total loss: 0.004681548103690147
# Parameter containing:
# tensor([[ 0.7160, -0.7130]], requires_grad=True)
# Epoch [160/500], Loss: 0.0047
# total loss: 0.004676362499594688
# Parameter containing:
# tensor([[ 0.7167, -0.7137]], requires_grad=True)
# Epoch [161/500], Loss: 0.0047
# total loss: 0.004671197384595871
# Parameter containing:
# tensor([[ 0.7174, -0.7144]], requires_grad=True)
# Epoch [162/500], Loss: 0.0047
# total loss: 0.004666052758693695
# Parameter containing:
# tensor([[ 0.7182, -0.7152]], requires_grad=True)
# Epoch [163/500], Loss: 0.0047
# total loss: 0.004660933278501034
# Parameter containing:
# tensor([[ 0.7189, -0.7159]], requires_grad=True)
# Epoch [164/500], Loss: 0.0047
# total loss: 0.004655835218727589
# Parameter containing:
# tensor([[ 0.7196, -0.7166]], requires_grad=True)
# Epoch [165/500], Loss: 0.0047
# total loss: 0.004650753457099199
# Parameter containing:
# tensor([[ 0.7203, -0.7173]], requires_grad=True)
# Epoch [166/500], Loss: 0.0047
# total loss: 0.004645699635148048
# Parameter containing:
# tensor([[ 0.7211, -0.7180]], requires_grad=True)
# Epoch [167/500], Loss: 0.0046
# total loss: 0.004640661180019379
# Parameter containing:
# tensor([[ 0.7218, -0.7188]], requires_grad=True)
# Epoch [168/500], Loss: 0.0046
# total loss: 0.004635648336261511
# Parameter containing:
# tensor([[ 0.7225, -0.7195]], requires_grad=True)
# Epoch [169/500], Loss: 0.0046
# total loss: 0.004630654118955135
# Parameter containing:
# tensor([[ 0.7232, -0.7202]], requires_grad=True)
# Epoch [170/500], Loss: 0.0046
# total loss: 0.004625680856406689
# Parameter containing:
# tensor([[ 0.7239, -0.7209]], requires_grad=True)
# Epoch [171/500], Loss: 0.0046
# total loss: 0.004620727151632309
# Parameter containing:
# tensor([[ 0.7246, -0.7216]], requires_grad=True)
# Epoch [172/500], Loss: 0.0046
# total loss: 0.004615795332938433
# Parameter containing:
# tensor([[ 0.7253, -0.7223]], requires_grad=True)
# Epoch [173/500], Loss: 0.0046
# total loss: 0.00461088540032506
# Parameter containing:
# tensor([[ 0.7260, -0.7230]], requires_grad=True)
# Epoch [174/500], Loss: 0.0046
# total loss: 0.004605990368872881
# Parameter containing:
# tensor([[ 0.7267, -0.7237]], requires_grad=True)
# Epoch [175/500], Loss: 0.0046
# total loss: 0.004601119086146355
# Parameter containing:
# tensor([[ 0.7274, -0.7244]], requires_grad=True)
# Epoch [176/500], Loss: 0.0046
# total loss: 0.004596265032887459
# Parameter containing:
# tensor([[ 0.7282, -0.7251]], requires_grad=True)
# Epoch [177/500], Loss: 0.0046
# total loss: 0.004591432865709066
# Parameter containing:
# tensor([[ 0.7289, -0.7258]], requires_grad=True)
# Epoch [178/500], Loss: 0.0046
# total loss: 0.004586618859320879
# Parameter containing:
# tensor([[ 0.7296, -0.7265]], requires_grad=True)
# Epoch [179/500], Loss: 0.0046
# total loss: 0.004581826739013195
# Parameter containing:
# tensor([[ 0.7303, -0.7272]], requires_grad=True)
# Epoch [180/500], Loss: 0.0046
# total loss: 0.004577051382511854
# Parameter containing:
# tensor([[ 0.7310, -0.7279]], requires_grad=True)
# Epoch [181/500], Loss: 0.0046
# total loss: 0.00457229558378458
# Parameter containing:
# tensor([[ 0.7316, -0.7286]], requires_grad=True)
# Epoch [182/500], Loss: 0.0046
# total loss: 0.004567558877170086
# Parameter containing:
# tensor([[ 0.7323, -0.7293]], requires_grad=True)
# Epoch [183/500], Loss: 0.0046
# total loss: 0.004562840331345797
# Parameter containing:
# tensor([[ 0.7330, -0.7300]], requires_grad=True)
# Epoch [184/500], Loss: 0.0046
# total loss: 0.004558142740279436
# Parameter containing:
# tensor([[ 0.7337, -0.7307]], requires_grad=True)
# Epoch [185/500], Loss: 0.0046
# total loss: 0.004553461447358131
# Parameter containing:
# tensor([[ 0.7344, -0.7314]], requires_grad=True)
# Epoch [186/500], Loss: 0.0046
# total loss: 0.004548799246549606
# Parameter containing:
# tensor([[ 0.7351, -0.7320]], requires_grad=True)
# Epoch [187/500], Loss: 0.0045
# total loss: 0.004544156603515148
# Parameter containing:
# tensor([[ 0.7358, -0.7327]], requires_grad=True)
# Epoch [188/500], Loss: 0.0045
# total loss: 0.004539527464658022
# Parameter containing:
# tensor([[ 0.7365, -0.7334]], requires_grad=True)
# Epoch [189/500], Loss: 0.0045
# total loss: 0.00453492347151041
# Parameter containing:
# tensor([[ 0.7372, -0.7341]], requires_grad=True)
# Epoch [190/500], Loss: 0.0045
# total loss: 0.004530330654233694
# Parameter containing:
# tensor([[ 0.7379, -0.7348]], requires_grad=True)
# Epoch [191/500], Loss: 0.0045
# total loss: 0.004525760654360056
# Parameter containing:
# tensor([[ 0.7385, -0.7354]], requires_grad=True)
# Epoch [192/500], Loss: 0.0045
# total loss: 0.004521204624325037
# Parameter containing:
# tensor([[ 0.7392, -0.7361]], requires_grad=True)
# Epoch [193/500], Loss: 0.0045
# total loss: 0.004516666755080223
# Parameter containing:
# tensor([[ 0.7399, -0.7368]], requires_grad=True)
# Epoch [194/500], Loss: 0.0045
# total loss: 0.004512148443609476
# Parameter containing:
# tensor([[ 0.7406, -0.7375]], requires_grad=True)
# Epoch [195/500], Loss: 0.0045
# total loss: 0.0045076473616063595
# Parameter containing:
# tensor([[ 0.7413, -0.7382]], requires_grad=True)
# Epoch [196/500], Loss: 0.0045
# total loss: 0.004503162577748299
# Parameter containing:
# tensor([[ 0.7419, -0.7388]], requires_grad=True)
# Epoch [197/500], Loss: 0.0045
# total loss: 0.004498694557696581
# Parameter containing:
# tensor([[ 0.7426, -0.7395]], requires_grad=True)
# Epoch [198/500], Loss: 0.0045
# total loss: 0.0044942437671124935
# Parameter containing:
# tensor([[ 0.7433, -0.7402]], requires_grad=True)
# Epoch [199/500], Loss: 0.0045
# total loss: 0.0044898102059960365
# Parameter containing:
# tensor([[ 0.7440, -0.7408]], requires_grad=True)
# Epoch [200/500], Loss: 0.0045
# total loss: 0.004485395736992359
# Parameter containing:
# tensor([[ 0.7446, -0.7415]], requires_grad=True)
# Epoch [201/500], Loss: 0.0045
# total loss: 0.0044809929095208645
# Parameter containing:
# tensor([[ 0.7453, -0.7422]], requires_grad=True)
# Epoch [202/500], Loss: 0.0045
# total loss: 0.004476609639823437
# Parameter containing:
# tensor([[ 0.7460, -0.7428]], requires_grad=True)
# Epoch [203/500], Loss: 0.0045
# total loss: 0.004472243133932352
# Parameter containing:
# tensor([[ 0.7466, -0.7435]], requires_grad=True)
# Epoch [204/500], Loss: 0.0045
# total loss: 0.004467891063541174
# Parameter containing:
# tensor([[ 0.7473, -0.7442]], requires_grad=True)
# Epoch [205/500], Loss: 0.0045
# total loss: 0.004463558550924063
# Parameter containing:
# tensor([[ 0.7480, -0.7448]], requires_grad=True)
# Epoch [206/500], Loss: 0.0045
# total loss: 0.004459237679839134
# Parameter containing:
# tensor([[ 0.7486, -0.7455]], requires_grad=True)
# Epoch [207/500], Loss: 0.0045
# total loss: 0.004454936366528273
# Parameter containing:
# tensor([[ 0.7493, -0.7461]], requires_grad=True)
# Epoch [208/500], Loss: 0.0045
# total loss: 0.004450647626072168
# Parameter containing:
# tensor([[ 0.7499, -0.7468]], requires_grad=True)
# Epoch [209/500], Loss: 0.0045
# total loss: 0.004446377977728844
# Parameter containing:
# tensor([[ 0.7506, -0.7475]], requires_grad=True)
# Epoch [210/500], Loss: 0.0044
# total loss: 0.004442123696208
# Parameter containing:
# tensor([[ 0.7513, -0.7481]], requires_grad=True)
# Epoch [211/500], Loss: 0.0044
# total loss: 0.0044378843158483505
# Parameter containing:
# tensor([[ 0.7519, -0.7488]], requires_grad=True)
# Epoch [212/500], Loss: 0.0044
# total loss: 0.004433660302311182
# Parameter containing:
# tensor([[ 0.7526, -0.7494]], requires_grad=True)
# Epoch [213/500], Loss: 0.0044
# total loss: 0.004429451189935207
# Parameter containing:
# tensor([[ 0.7532, -0.7501]], requires_grad=True)
# Epoch [214/500], Loss: 0.0044
# total loss: 0.0044252583757042885
# Parameter containing:
# tensor([[ 0.7539, -0.7507]], requires_grad=True)
# Epoch [215/500], Loss: 0.0044
# total loss: 0.004421079531311989
# Parameter containing:
# tensor([[ 0.7545, -0.7514]], requires_grad=True)
# Epoch [216/500], Loss: 0.0044
# total loss: 0.00441691605374217
# Parameter containing:
# tensor([[ 0.7552, -0.7520]], requires_grad=True)
# Epoch [217/500], Loss: 0.0044
# total loss: 0.004412767477333546
# Parameter containing:
# tensor([[ 0.7558, -0.7527]], requires_grad=True)
# Epoch [218/500], Loss: 0.0044
# total loss: 0.004408635199069977
# Parameter containing:
# tensor([[ 0.7565, -0.7533]], requires_grad=True)
# Epoch [219/500], Loss: 0.0044
# total loss: 0.00440451642498374
# Parameter containing:
# tensor([[ 0.7571, -0.7540]], requires_grad=True)
# Epoch [220/500], Loss: 0.0044
# total loss: 0.004400413483381271
# Parameter containing:
# tensor([[ 0.7578, -0.7546]], requires_grad=True)
# Epoch [221/500], Loss: 0.0044
# total loss: 0.004396325442939997
# Parameter containing:
# tensor([[ 0.7584, -0.7552]], requires_grad=True)
# Epoch [222/500], Loss: 0.0044
# total loss: 0.00439224811270833
# Parameter containing:
# tensor([[ 0.7591, -0.7559]], requires_grad=True)
# Epoch [223/500], Loss: 0.0044
# total loss: 0.004388188943266869
# Parameter containing:
# tensor([[ 0.7597, -0.7565]], requires_grad=True)
# Epoch [224/500], Loss: 0.0044
# total loss: 0.004384143743664026
# Parameter containing:
# tensor([[ 0.7604, -0.7572]], requires_grad=True)
# Epoch [225/500], Loss: 0.0044
# total loss: 0.0043801129795610905
# Parameter containing:
# tensor([[ 0.7610, -0.7578]], requires_grad=True)
# Epoch [226/500], Loss: 0.0044
# total loss: 0.004376098047941923
# Parameter containing:
# tensor([[ 0.7616, -0.7584]], requires_grad=True)
# Epoch [227/500], Loss: 0.0044
# total loss: 0.004372093360871077
# Parameter containing:
# tensor([[ 0.7623, -0.7591]], requires_grad=True)
# Epoch [228/500], Loss: 0.0044
# total loss: 0.00436810590326786
# Parameter containing:
# tensor([[ 0.7629, -0.7597]], requires_grad=True)
# Epoch [229/500], Loss: 0.0044
# total loss: 0.004364130087196827
# Parameter containing:
# tensor([[ 0.7635, -0.7603]], requires_grad=True)
# Epoch [230/500], Loss: 0.0044
# total loss: 0.004360167775303125
# Parameter containing:
# tensor([[ 0.7642, -0.7610]], requires_grad=True)
# Epoch [231/500], Loss: 0.0044
# total loss: 0.0043562231585383415
# Parameter containing:
# tensor([[ 0.7648, -0.7616]], requires_grad=True)
# Epoch [232/500], Loss: 0.0044
# total loss: 0.004352289251983166
# Parameter containing:
# tensor([[ 0.7654, -0.7622]], requires_grad=True)
# Epoch [233/500], Loss: 0.0044
# total loss: 0.004348369315266609
# Parameter containing:
# tensor([[ 0.7661, -0.7629]], requires_grad=True)
# Epoch [234/500], Loss: 0.0043
# total loss: 0.004344461020082235
# Parameter containing:
# tensor([[ 0.7667, -0.7635]], requires_grad=True)
# Epoch [235/500], Loss: 0.0043
# total loss: 0.00434056855738163
# Parameter containing:
# tensor([[ 0.7673, -0.7641]], requires_grad=True)
# Epoch [236/500], Loss: 0.0043
# total loss: 0.004336690995842218
# Parameter containing:
# tensor([[ 0.7680, -0.7647]], requires_grad=True)
# Epoch [237/500], Loss: 0.0043
# total loss: 0.004332822747528553
# Parameter containing:
# tensor([[ 0.7686, -0.7654]], requires_grad=True)
# Epoch [238/500], Loss: 0.0043
# total loss: 0.004328968934714794
# Parameter containing:
# tensor([[ 0.7692, -0.7660]], requires_grad=True)
# Epoch [239/500], Loss: 0.0043
# total loss: 0.004325130023062229
# Parameter containing:
# tensor([[ 0.7698, -0.7666]], requires_grad=True)
# Epoch [240/500], Loss: 0.0043
# total loss: 0.0043213036842644215
# Parameter containing:
# tensor([[ 0.7705, -0.7672]], requires_grad=True)
# Epoch [241/500], Loss: 0.0043
# total loss: 0.004317488521337509
# Parameter containing:
# tensor([[ 0.7711, -0.7679]], requires_grad=True)
# Epoch [242/500], Loss: 0.0043
# total loss: 0.004313689190894365
# Parameter containing:
# tensor([[ 0.7717, -0.7685]], requires_grad=True)
# Epoch [243/500], Loss: 0.0043
# total loss: 0.004309899639338255
# Parameter containing:
# tensor([[ 0.7723, -0.7691]], requires_grad=True)
# Epoch [244/500], Loss: 0.0043
# total loss: 0.004306122660636902
# Parameter containing:
# tensor([[ 0.7730, -0.7697]], requires_grad=True)
# Epoch [245/500], Loss: 0.0043
# total loss: 0.0043023619800806046
# Parameter containing:
# tensor([[ 0.7736, -0.7703]], requires_grad=True)
# Epoch [246/500], Loss: 0.0043
# total loss: 0.0042986092157661915
# Parameter containing:
# tensor([[ 0.7742, -0.7709]], requires_grad=True)
# Epoch [247/500], Loss: 0.0043
# total loss: 0.004294872749596834
# Parameter containing:
# tensor([[ 0.7748, -0.7716]], requires_grad=True)
# Epoch [248/500], Loss: 0.0043
# total loss: 0.0042911493219435215
# Parameter containing:
# tensor([[ 0.7754, -0.7722]], requires_grad=True)
# Epoch [249/500], Loss: 0.0043
# total loss: 0.00428743427619338
# Parameter containing:
# tensor([[ 0.7760, -0.7728]], requires_grad=True)
# Epoch [250/500], Loss: 0.0043
# total loss: 0.004283732734620571
# Parameter containing:
# tensor([[ 0.7767, -0.7734]], requires_grad=True)
# Epoch [251/500], Loss: 0.0043
# total loss: 0.004280046559870243
# Parameter containing:
# tensor([[ 0.7773, -0.7740]], requires_grad=True)
# Epoch [252/500], Loss: 0.0043
# total loss: 0.004276371095329523
# Parameter containing:
# tensor([[ 0.7779, -0.7746]], requires_grad=True)
# Epoch [253/500], Loss: 0.0043
# total loss: 0.0042727054096758366
# Parameter containing:
# tensor([[ 0.7785, -0.7752]], requires_grad=True)
# Epoch [254/500], Loss: 0.0043
# total loss: 0.004269051365554333
# Parameter containing:
# tensor([[ 0.7791, -0.7758]], requires_grad=True)
# Epoch [255/500], Loss: 0.0043
# total loss: 0.004265415016561747
# Parameter containing:
# tensor([[ 0.7797, -0.7764]], requires_grad=True)
# Epoch [256/500], Loss: 0.0043
# total loss: 0.00426178565248847
# Parameter containing:
# tensor([[ 0.7803, -0.7770]], requires_grad=True)
# Epoch [257/500], Loss: 0.0043
# total loss: 0.004258166998624802
# Parameter containing:
# tensor([[ 0.7809, -0.7776]], requires_grad=True)
# Epoch [258/500], Loss: 0.0043
# total loss: 0.004254561848938465
# Parameter containing:
# tensor([[ 0.7815, -0.7782]], requires_grad=True)
# Epoch [259/500], Loss: 0.0043
# total loss: 0.004250969272106886
# Parameter containing:
# tensor([[ 0.7821, -0.7788]], requires_grad=True)
# Epoch [260/500], Loss: 0.0043
# total loss: 0.00424738647416234
# Parameter containing:
# tensor([[ 0.7827, -0.7794]], requires_grad=True)
# Epoch [261/500], Loss: 0.0042
# total loss: 0.004243819043040276
# Parameter containing:
# tensor([[ 0.7833, -0.7800]], requires_grad=True)
# Epoch [262/500], Loss: 0.0042
# total loss: 0.004240260925143957
# Parameter containing:
# tensor([[ 0.7839, -0.7806]], requires_grad=True)
# Epoch [263/500], Loss: 0.0042
# total loss: 0.004236714914441109
# Parameter containing:
# tensor([[ 0.7845, -0.7812]], requires_grad=True)
# Epoch [264/500], Loss: 0.0042
# total loss: 0.004233177751302719
# Parameter containing:
# tensor([[ 0.7851, -0.7818]], requires_grad=True)
# Epoch [265/500], Loss: 0.0042
# total loss: 0.004229651764035225
# Parameter containing:
# tensor([[ 0.7857, -0.7824]], requires_grad=True)
# Epoch [266/500], Loss: 0.0042
# total loss: 0.004226141609251499
# Parameter containing:
# tensor([[ 0.7863, -0.7830]], requires_grad=True)
# Epoch [267/500], Loss: 0.0042
# total loss: 0.004222639370709658
# Parameter containing:
# tensor([[ 0.7869, -0.7836]], requires_grad=True)
# Epoch [268/500], Loss: 0.0042
# total loss: 0.004219147376716137
# Parameter containing:
# tensor([[ 0.7875, -0.7842]], requires_grad=True)
# Epoch [269/500], Loss: 0.0042
# total loss: 0.004215666092932224
# Parameter containing:
# tensor([[ 0.7881, -0.7848]], requires_grad=True)
# Epoch [270/500], Loss: 0.0042
# total loss: 0.0042121997103095055
# Parameter containing:
# tensor([[ 0.7887, -0.7854]], requires_grad=True)
# Epoch [271/500], Loss: 0.0042
# total loss: 0.004208740778267384
# Parameter containing:
# tensor([[ 0.7893, -0.7860]], requires_grad=True)
# Epoch [272/500], Loss: 0.0042
# total loss: 0.004205293487757444
# Parameter containing:
# tensor([[ 0.7899, -0.7866]], requires_grad=True)
# Epoch [273/500], Loss: 0.0042
# total loss: 0.004201858304440975
# Parameter containing:
# tensor([[ 0.7905, -0.7872]], requires_grad=True)
# Epoch [274/500], Loss: 0.0042
# total loss: 0.004198433831334114
# Parameter containing:
# tensor([[ 0.7911, -0.7878]], requires_grad=True)
# Epoch [275/500], Loss: 0.0042
# total loss: 0.0041950177401304245
# Parameter containing:
# tensor([[ 0.7917, -0.7883]], requires_grad=True)
# Epoch [276/500], Loss: 0.0042
# total loss: 0.004191616550087929
# Parameter containing:
# tensor([[ 0.7923, -0.7889]], requires_grad=True)
# Epoch [277/500], Loss: 0.0042
# total loss: 0.004188222344964743
# Parameter containing:
# tensor([[ 0.7928, -0.7895]], requires_grad=True)
# Epoch [278/500], Loss: 0.0042
# total loss: 0.00418483791872859
# Parameter containing:
# tensor([[ 0.7934, -0.7901]], requires_grad=True)
# Epoch [279/500], Loss: 0.0042
# total loss: 0.004181464668363333
# Parameter containing:
# tensor([[ 0.7940, -0.7907]], requires_grad=True)
# Epoch [280/500], Loss: 0.0042
# total loss: 0.004178103990852833
# Parameter containing:
# tensor([[ 0.7946, -0.7913]], requires_grad=True)
# Epoch [281/500], Loss: 0.0042
# total loss: 0.0041747502982616425
# Parameter containing:
# tensor([[ 0.7952, -0.7918]], requires_grad=True)
# Epoch [282/500], Loss: 0.0042
# total loss: 0.004171410575509071
# Parameter containing:
# tensor([[ 0.7958, -0.7924]], requires_grad=True)
# Epoch [283/500], Loss: 0.0042
# total loss: 0.004168078303337097
# Parameter containing:
# tensor([[ 0.7964, -0.7930]], requires_grad=True)
# Epoch [284/500], Loss: 0.0042
# total loss: 0.00416475860401988
# Parameter containing:
# tensor([[ 0.7969, -0.7936]], requires_grad=True)
# Epoch [285/500], Loss: 0.0042
# total loss: 0.00416144635528326
# Parameter containing:
# tensor([[ 0.7975, -0.7942]], requires_grad=True)
# Epoch [286/500], Loss: 0.0042
# total loss: 0.0041581448167562485
# Parameter containing:
# tensor([[ 0.7981, -0.7947]], requires_grad=True)
# Epoch [287/500], Loss: 0.0042
# total loss: 0.004154855851083994
# Parameter containing:
# tensor([[ 0.7987, -0.7953]], requires_grad=True)
# Epoch [288/500], Loss: 0.0042
# total loss: 0.004151574335992336
# Parameter containing:
# tensor([[ 0.7992, -0.7959]], requires_grad=True)
# Epoch [289/500], Loss: 0.0042
# total loss: 0.004148303996771574
# Parameter containing:
# tensor([[ 0.7998, -0.7965]], requires_grad=True)
# Epoch [290/500], Loss: 0.0041
# total loss: 0.004145042039453983
# Parameter containing:
# tensor([[ 0.8004, -0.7970]], requires_grad=True)
# Epoch [291/500], Loss: 0.0041
# total loss: 0.004141791258007288
# Parameter containing:
# tensor([[ 0.8010, -0.7976]], requires_grad=True)
# Epoch [292/500], Loss: 0.0041
# total loss: 0.0041385493241250515
# Parameter containing:
# tensor([[ 0.8015, -0.7982]], requires_grad=True)
# Epoch [293/500], Loss: 0.0041
# total loss: 0.00413531856611371
# Parameter containing:
# tensor([[ 0.8021, -0.7987]], requires_grad=True)
# Epoch [294/500], Loss: 0.0041
# total loss: 0.004132095258682966
# Parameter containing:
# tensor([[ 0.8027, -0.7993]], requires_grad=True)
# Epoch [295/500], Loss: 0.0041
# total loss: 0.00412888266146183
# Parameter containing:
# tensor([[ 0.8033, -0.7999]], requires_grad=True)
# Epoch [296/500], Loss: 0.0041
# total loss: 0.004125678911805153
# Parameter containing:
# tensor([[ 0.8038, -0.8005]], requires_grad=True)
# Epoch [297/500], Loss: 0.0041
# total loss: 0.004122484475374222
# Parameter containing:
# tensor([[ 0.8044, -0.8010]], requires_grad=True)
# Epoch [298/500], Loss: 0.0041
# total loss: 0.004119303077459335
# Parameter containing:
# tensor([[ 0.8050, -0.8016]], requires_grad=True)
# Epoch [299/500], Loss: 0.0041
# total loss: 0.0041161272674798965
# Parameter containing:
# tensor([[ 0.8055, -0.8022]], requires_grad=True)
# Epoch [300/500], Loss: 0.0041
# total loss: 0.004112962633371353
# Parameter containing:
# tensor([[ 0.8061, -0.8027]], requires_grad=True)
# Epoch [301/500], Loss: 0.0041
# total loss: 0.004109805915504694
# Parameter containing:
# tensor([[ 0.8067, -0.8033]], requires_grad=True)
# Epoch [302/500], Loss: 0.0041
# total loss: 0.004106659907847643
# Parameter containing:
# tensor([[ 0.8072, -0.8038]], requires_grad=True)
# Epoch [303/500], Loss: 0.0041
# total loss: 0.004103520419448614
# Parameter containing:
# tensor([[ 0.8078, -0.8044]], requires_grad=True)
# Epoch [304/500], Loss: 0.0041
# total loss: 0.004100392572581768
# Parameter containing:
# tensor([[ 0.8084, -0.8050]], requires_grad=True)
# Epoch [305/500], Loss: 0.0041
# total loss: 0.004097274970263243
# Parameter containing:
# tensor([[ 0.8089, -0.8055]], requires_grad=True)
# Epoch [306/500], Loss: 0.0041
# total loss: 0.004094164818525314
# Parameter containing:
# tensor([[ 0.8095, -0.8061]], requires_grad=True)
# Epoch [307/500], Loss: 0.0041
# total loss: 0.004091064445674419
# Parameter containing:
# tensor([[ 0.8101, -0.8066]], requires_grad=True)
# Epoch [308/500], Loss: 0.0041
# total loss: 0.004087971989065409
# Parameter containing:
# tensor([[ 0.8106, -0.8072]], requires_grad=True)
# Epoch [309/500], Loss: 0.0041
# total loss: 0.004084890242666006
# Parameter containing:
# tensor([[ 0.8112, -0.8078]], requires_grad=True)
# Epoch [310/500], Loss: 0.0041
# total loss: 0.004081814084202051
# Parameter containing:
# tensor([[ 0.8117, -0.8083]], requires_grad=True)
# Epoch [311/500], Loss: 0.0041
# total loss: 0.004078748635947704
# Parameter containing:
# tensor([[ 0.8123, -0.8089]], requires_grad=True)
# Epoch [312/500], Loss: 0.0041
# total loss: 0.004075693432241678
# Parameter containing:
# tensor([[ 0.8128, -0.8094]], requires_grad=True)
# Epoch [313/500], Loss: 0.0041
# total loss: 0.0040726433508098125
# Parameter containing:
# tensor([[ 0.8134, -0.8100]], requires_grad=True)
# Epoch [314/500], Loss: 0.0041
# total loss: 0.0040696049109101295
# Parameter containing:
# tensor([[ 0.8140, -0.8105]], requires_grad=True)
# Epoch [315/500], Loss: 0.0041
# total loss: 0.004066574852913618
# Parameter containing:
# tensor([[ 0.8145, -0.8111]], requires_grad=True)
# Epoch [316/500], Loss: 0.0041
# total loss: 0.004063555039465427
# Parameter containing:
# tensor([[ 0.8151, -0.8116]], requires_grad=True)
# Epoch [317/500], Loss: 0.0041
# total loss: 0.004060542210936546
# Parameter containing:
# tensor([[ 0.8156, -0.8122]], requires_grad=True)
# Epoch [318/500], Loss: 0.0041
# total loss: 0.0040575372986495495
# Parameter containing:
# tensor([[ 0.8162, -0.8127]], requires_grad=True)
# Epoch [319/500], Loss: 0.0041
# total loss: 0.004054540302604437
# Parameter containing:
# tensor([[ 0.8167, -0.8133]], requires_grad=True)
# Epoch [320/500], Loss: 0.0041
# total loss: 0.004051553551107645
# Parameter containing:
# tensor([[ 0.8173, -0.8138]], requires_grad=True)
# Epoch [321/500], Loss: 0.0041
# total loss: 0.004048572387546301
# Parameter containing:
# tensor([[ 0.8178, -0.8144]], requires_grad=True)
# Epoch [322/500], Loss: 0.0040
# total loss: 0.004045603331178427
# Parameter containing:
# tensor([[ 0.8184, -0.8149]], requires_grad=True)
# Epoch [323/500], Loss: 0.0040
# total loss: 0.004042639862746
# Parameter containing:
# tensor([[ 0.8189, -0.8155]], requires_grad=True)
# Epoch [324/500], Loss: 0.0040
# total loss: 0.004039686638861895
# Parameter containing:
# tensor([[ 0.8195, -0.8160]], requires_grad=True)
# Epoch [325/500], Loss: 0.0040
# total loss: 0.004036737140268087
# Parameter containing:
# tensor([[ 0.8200, -0.8166]], requires_grad=True)
# Epoch [326/500], Loss: 0.0040
# total loss: 0.004033801145851612
# Parameter containing:
# tensor([[ 0.8206, -0.8171]], requires_grad=True)
# Epoch [327/500], Loss: 0.0040
# total loss: 0.004030872136354446
# Parameter containing:
# tensor([[ 0.8211, -0.8177]], requires_grad=True)
# Epoch [328/500], Loss: 0.0040
# total loss: 0.004027952440083027
# Parameter containing:
# tensor([[ 0.8217, -0.8182]], requires_grad=True)
# Epoch [329/500], Loss: 0.0040
# total loss: 0.004025037866085768
# Parameter containing:
# tensor([[ 0.8222, -0.8187]], requires_grad=True)
# Epoch [330/500], Loss: 0.0040
# total loss: 0.0040221307426691055
# Parameter containing:
# tensor([[ 0.8227, -0.8193]], requires_grad=True)
# Epoch [331/500], Loss: 0.0040
# total loss: 0.004019236657768488
# Parameter containing:
# tensor([[ 0.8233, -0.8198]], requires_grad=True)
# Epoch [332/500], Loss: 0.0040
# total loss: 0.004016344901174307
# Parameter containing:
# tensor([[ 0.8238, -0.8204]], requires_grad=True)
# Epoch [333/500], Loss: 0.0040
# total loss: 0.004013463854789734
# Parameter containing:
# tensor([[ 0.8244, -0.8209]], requires_grad=True)
# Epoch [334/500], Loss: 0.0040
# total loss: 0.004010592587292194
# Parameter containing:
# tensor([[ 0.8249, -0.8214]], requires_grad=True)
# Epoch [335/500], Loss: 0.0040
# total loss: 0.004007723648101091
# Parameter containing:
# tensor([[ 0.8254, -0.8220]], requires_grad=True)
# Epoch [336/500], Loss: 0.0040
# total loss: 0.004004868678748608
# Parameter containing:
# tensor([[ 0.8260, -0.8225]], requires_grad=True)
# Epoch [337/500], Loss: 0.0040
# total loss: 0.004002017434686422
# Parameter containing:
# tensor([[ 0.8265, -0.8230]], requires_grad=True)
# Epoch [338/500], Loss: 0.0040
# total loss: 0.0039991759695112705
# Parameter containing:
# tensor([[ 0.8271, -0.8236]], requires_grad=True)
# Epoch [339/500], Loss: 0.0040
# total loss: 0.003996341489255428
# Parameter containing:
# tensor([[ 0.8276, -0.8241]], requires_grad=True)
# Epoch [340/500], Loss: 0.0040
# total loss: 0.003993516322225332
# Parameter containing:
# tensor([[ 0.8281, -0.8246]], requires_grad=True)
# Epoch [341/500], Loss: 0.0040
# total loss: 0.003990694880485535
# Parameter containing:
# tensor([[ 0.8287, -0.8252]], requires_grad=True)
# Epoch [342/500], Loss: 0.0040
# total loss: 0.003987884148955345
# Parameter containing:
# tensor([[ 0.8292, -0.8257]], requires_grad=True)
# Epoch [343/500], Loss: 0.0040
# total loss: 0.003985080402344465
# Parameter containing:
# tensor([[ 0.8297, -0.8262]], requires_grad=True)
# Epoch [344/500], Loss: 0.0040
# total loss: 0.003982281778007746
# Parameter containing:
# tensor([[ 0.8303, -0.8268]], requires_grad=True)
# Epoch [345/500], Loss: 0.0040
# total loss: 0.003979492466896772
# Parameter containing:
# tensor([[ 0.8308, -0.8273]], requires_grad=True)
# Epoch [346/500], Loss: 0.0040
# total loss: 0.003976714797317982
# Parameter containing:
# tensor([[ 0.8313, -0.8278]], requires_grad=True)
# Epoch [347/500], Loss: 0.0040
# total loss: 0.003973937593400478
# Parameter containing:
# tensor([[ 0.8319, -0.8284]], requires_grad=True)
# Epoch [348/500], Loss: 0.0040
# total loss: 0.00397117156535387
# Parameter containing:
# tensor([[ 0.8324, -0.8289]], requires_grad=True)
# Epoch [349/500], Loss: 0.0040
# total loss: 0.003968411590903997
# Parameter containing:
# tensor([[ 0.8329, -0.8294]], requires_grad=True)
# Epoch [350/500], Loss: 0.0040
# total loss: 0.003965659998357296
# Parameter containing:
# tensor([[ 0.8335, -0.8299]], requires_grad=True)
# Epoch [351/500], Loss: 0.0040
# total loss: 0.0039629158563911915
# Parameter containing:
# tensor([[ 0.8340, -0.8305]], requires_grad=True)
# Epoch [352/500], Loss: 0.0040
# total loss: 0.003960181027650833
# Parameter containing:
# tensor([[ 0.8345, -0.8310]], requires_grad=True)
# Epoch [353/500], Loss: 0.0040
# total loss: 0.003957448061555624
# Parameter containing:
# tensor([[ 0.8350, -0.8315]], requires_grad=True)
# Epoch [354/500], Loss: 0.0040
# total loss: 0.003954725340008736
# Parameter containing:
# tensor([[ 0.8356, -0.8320]], requires_grad=True)
# Epoch [355/500], Loss: 0.0040
# total loss: 0.003952011000365019
# Parameter containing:
# tensor([[ 0.8361, -0.8326]], requires_grad=True)
# Epoch [356/500], Loss: 0.0040
# total loss: 0.003949303179979324
# Parameter containing:
# tensor([[ 0.8366, -0.8331]], requires_grad=True)
# Epoch [357/500], Loss: 0.0039
# total loss: 0.00394660048186779
# Parameter containing:
# tensor([[ 0.8371, -0.8336]], requires_grad=True)
# Epoch [358/500], Loss: 0.0039
# total loss: 0.00394390569999814
# Parameter containing:
# tensor([[ 0.8377, -0.8341]], requires_grad=True)
# Epoch [359/500], Loss: 0.0039
# ...
# Parameter containing:
# tensor([[ 0.8495, -0.8459]], requires_grad=True)
# Epoch [382/500], Loss: 0.0039
# total loss: 0.00388127937912941
# Parameter containing:
# tensor([[ 0.8500, -0.8464]], requires_grad=True)
# Epoch [383/500], Loss: 0.0039
# total loss: 0.0038787522353231907
# Parameter containing:
# tensor([[ 0.8505, -0.8469]], requires_grad=True)
# Epoch [384/500], Loss: 0.0039
# total loss: 0.0038762285839766264
# Parameter containing:
# tensor([[ 0.8510, -0.8474]], requires_grad=True)
# Epoch [385/500], Loss: 0.0039
# total loss: 0.00387371308170259
# Parameter containing:
# tensor([[ 0.8515, -0.8479]], requires_grad=True)
# Epoch [386/500], Loss: 0.0039
# total loss: 0.003871204797178507
# Parameter containing:
# tensor([[ 0.8520, -0.8484]], requires_grad=True)
# Epoch [387/500], Loss: 0.0039
# total loss: 0.003868700470775366
# Parameter containing:
# tensor([[ 0.8525, -0.8489]], requires_grad=True)
# Epoch [388/500], Loss: 0.0039
# total loss: 0.003866206156089902
# Parameter containing:
# tensor([[ 0.8530, -0.8494]], requires_grad=True)
# Epoch [389/500], Loss: 0.0039
# total loss: 0.0038637132383883
# Parameter containing:
# tensor([[ 0.8535, -0.8499]], requires_grad=True)
# Epoch [390/500], Loss: 0.0039
# total loss: 0.003861232427880168
# Parameter containing:
# tensor([[ 0.8540, -0.8504]], requires_grad=True)
# Epoch [391/500], Loss: 0.0039
# total loss: 0.003858753014355898
# Parameter containing:
# tensor([[ 0.8545, -0.8509]], requires_grad=True)
# Epoch [392/500], Loss: 0.0039
# total loss: 0.0038562840782105923
# Parameter containing:
# tensor([[ 0.8550, -0.8514]], requires_grad=True)
# Epoch [393/500], Loss: 0.0039
# total loss: 0.0038538130465894938
# Parameter containing:
# tensor([[ 0.8555, -0.8519]], requires_grad=True)
# Epoch [394/500], Loss: 0.0039
# total loss: 0.003851354820653796
# Parameter containing:
# tensor([[ 0.8560, -0.8524]], requires_grad=True)
# Epoch [395/500], Loss: 0.0039
# total loss: 0.0038489019498229027
# Parameter containing:
# tensor([[ 0.8565, -0.8529]], requires_grad=True)
# Epoch [396/500], Loss: 0.0038
# total loss: 0.0038464535027742386
# Parameter containing:
# tensor([[ 0.8570, -0.8534]], requires_grad=True)
# Epoch [397/500], Loss: 0.0038
# total loss: 0.0038440104108303785
# Parameter containing:
# tensor([[ 0.8575, -0.8539]], requires_grad=True)
# Epoch [398/500], Loss: 0.0038
# total loss: 0.0038415745366364717
# Parameter containing:
# tensor([[ 0.8580, -0.8544]], requires_grad=True)
# Epoch [399/500], Loss: 0.0038
# total loss: 0.0038391451817005873
# Parameter containing:
# tensor([[ 0.8585, -0.8549]], requires_grad=True)
# Epoch [400/500], Loss: 0.0038
# total loss: 0.0038367225788533688
# Parameter containing:
# tensor([[ 0.8590, -0.8554]], requires_grad=True)
# Epoch [401/500], Loss: 0.0038
# total loss: 0.0038343025371432304
# Parameter containing:
# tensor([[ 0.8595, -0.8559]], requires_grad=True)
# Epoch [402/500], Loss: 0.0038
# total loss: 0.0038318908773362637
# Parameter containing:
# tensor([[ 0.8600, -0.8564]], requires_grad=True)
# Epoch [403/500], Loss: 0.0038
# total loss: 0.00382948387414217
# Parameter containing:
# tensor([[ 0.8605, -0.8569]], requires_grad=True)
# Epoch [404/500], Loss: 0.0038
# total loss: 0.0038270822260528803
# Parameter containing:
# tensor([[ 0.8610, -0.8574]], requires_grad=True)
# Epoch [405/500], Loss: 0.0038
# total loss: 0.0038246866315603256
# Parameter containing:
# tensor([[ 0.8615, -0.8578]], requires_grad=True)
# Epoch [406/500], Loss: 0.0038
# total loss: 0.0038222947623580694
# Parameter containing:
# tensor([[ 0.8620, -0.8583]], requires_grad=True)
# Epoch [407/500], Loss: 0.0038
# total loss: 0.0038199133705347776
# Parameter containing:
# tensor([[ 0.8625, -0.8588]], requires_grad=True)
# Epoch [408/500], Loss: 0.0038
# total loss: 0.0038175350055098534
# Parameter containing:
# tensor([[ 0.8630, -0.8593]], requires_grad=True)
# Epoch [409/500], Loss: 0.0038
# total loss: 0.0038151636254042387
# Parameter containing:
# tensor([[ 0.8635, -0.8598]], requires_grad=True)
# Epoch [410/500], Loss: 0.0038
# total loss: 0.0038127938751131296
# Parameter containing:
# tensor([[ 0.8639, -0.8603]], requires_grad=True)
# Epoch [411/500], Loss: 0.0038
# total loss: 0.0038104350678622723
# Parameter containing:
# tensor([[ 0.8644, -0.8608]], requires_grad=True)
# Epoch [412/500], Loss: 0.0038
# total loss: 0.0038080778904259205
# Parameter containing:
# tensor([[ 0.8649, -0.8613]], requires_grad=True)
# Epoch [413/500], Loss: 0.0038
# total loss: 0.003805727930739522
# Parameter containing:
# tensor([[ 0.8654, -0.8617]], requires_grad=True)
# Epoch [414/500], Loss: 0.0038
# total loss: 0.0038033840246498585
# Parameter containing:
# tensor([[ 0.8659, -0.8622]], requires_grad=True)
# Epoch [415/500], Loss: 0.0038
# total loss: 0.0038010443095117807
# Parameter containing:
# tensor([[ 0.8664, -0.8627]], requires_grad=True)
# Epoch [416/500], Loss: 0.0038
# total loss: 0.0037987101823091507
# Parameter containing:
# tensor([[ 0.8669, -0.8632]], requires_grad=True)
# Epoch [417/500], Loss: 0.0038
# total loss: 0.003796383971348405
# Parameter containing:
# tensor([[ 0.8674, -0.8637]], requires_grad=True)
# Epoch [418/500], Loss: 0.0038
# total loss: 0.0037940603215247393
# Parameter containing:
# tensor([[ 0.8678, -0.8642]], requires_grad=True)
# Epoch [419/500], Loss: 0.0038
# total loss: 0.003791742492467165
# Parameter containing:
# tensor([[ 0.8683, -0.8646]], requires_grad=True)
# Epoch [420/500], Loss: 0.0038
# total loss: 0.0037894328124821186
# Parameter containing:
# tensor([[ 0.8688, -0.8651]], requires_grad=True)
# Epoch [421/500], Loss: 0.0038
# total loss: 0.0037871256936341524
# Parameter containing:
# tensor([[ 0.8693, -0.8656]], requires_grad=True)
# Epoch [422/500], Loss: 0.0038
# total loss: 0.003784822067245841
# Parameter containing:
# tensor([[ 0.8698, -0.8661]], requires_grad=True)
# Epoch [423/500], Loss: 0.0038
# total loss: 0.0037825254257768393
# Parameter containing:
# tensor([[ 0.8703, -0.8666]], requires_grad=True)
# Epoch [424/500], Loss: 0.0038
# total loss: 0.0037802348379045725
# Parameter containing:
# tensor([[ 0.8707, -0.8670]], requires_grad=True)
# Epoch [425/500], Loss: 0.0038
# total loss: 0.00377795216627419
# Parameter containing:
# tensor([[ 0.8712, -0.8675]], requires_grad=True)
# Epoch [426/500], Loss: 0.0038
# total loss: 0.0037756722886115313
# Parameter containing:
# tensor([[ 0.8717, -0.8680]], requires_grad=True)
# Epoch [427/500], Loss: 0.0038
# total loss: 0.003773398231714964
# Parameter containing:
# tensor([[ 0.8722, -0.8685]], requires_grad=True)
# Epoch [428/500], Loss: 0.0038
# total loss: 0.0037711276672780514
# Parameter containing:
# tensor([[ 0.8727, -0.8690]], requires_grad=True)
# Epoch [429/500], Loss: 0.0038
# total loss: 0.003768863156437874
# Parameter containing:
# tensor([[ 0.8731, -0.8694]], requires_grad=True)
# Epoch [430/500], Loss: 0.0038
# total loss: 0.003766605630517006
# Parameter containing:
# tensor([[ 0.8736, -0.8699]], requires_grad=True)
# Epoch [431/500], Loss: 0.0038
# total loss: 0.0037643504329025745
# Parameter containing:
# tensor([[ 0.8741, -0.8704]], requires_grad=True)
# Epoch [432/500], Loss: 0.0038
# total loss: 0.00376210268586874
# Parameter containing:
# tensor([[ 0.8746, -0.8709]], requires_grad=True)
# Epoch [433/500], Loss: 0.0038
# total loss: 0.003759859362617135
# Parameter containing:
# tensor([[ 0.8751, -0.8713]], requires_grad=True)
# Epoch [434/500], Loss: 0.0038
# total loss: 0.0037576218601316214
# Parameter containing:
# tensor([[ 0.8755, -0.8718]], requires_grad=True)
# Epoch [435/500], Loss: 0.0038
# total loss: 0.0037553871516138315
# Parameter containing:
# tensor([[ 0.8760, -0.8723]], requires_grad=True)
# Epoch [436/500], Loss: 0.0038
# total loss: 0.0037531584966927767
# Parameter containing:
# tensor([[ 0.8765, -0.8728]], requires_grad=True)
# Epoch [437/500], Loss: 0.0038
# total loss: 0.0037509333342313766
# Parameter containing:
# tensor([[ 0.8770, -0.8732]], requires_grad=True)
# Epoch [438/500], Loss: 0.0038
# total loss: 0.0037487174849957228
# Parameter containing:
# tensor([[ 0.8774, -0.8737]], requires_grad=True)
# Epoch [439/500], Loss: 0.0037
# total loss: 0.003746502334252
# Parameter containing:
# tensor([[ 0.8779, -0.8742]], requires_grad=True)
# Epoch [440/500], Loss: 0.0037
# total loss: 0.0037442974280565977
# Parameter containing:
# tensor([[ 0.8784, -0.8746]], requires_grad=True)
# Epoch [441/500], Loss: 0.0037
# total loss: 0.0037420932203531265
# Parameter containing:
# tensor([[ 0.8789, -0.8751]], requires_grad=True)
# Epoch [442/500], Loss: 0.0037
# total loss: 0.003739893902093172
# Parameter containing:
# tensor([[ 0.8793, -0.8756]], requires_grad=True)
# Epoch [443/500], Loss: 0.0037
# total loss: 0.0037377008702605963
# Parameter containing:
# tensor([[ 0.8798, -0.8761]], requires_grad=True)
# Epoch [444/500], Loss: 0.0037
# total loss: 0.0037355150561779737
# Parameter containing:
# tensor([[ 0.8803, -0.8765]], requires_grad=True)
# Epoch [445/500], Loss: 0.0037
# total loss: 0.003733329474925995
# Parameter containing:
# tensor([[ 0.8807, -0.8770]], requires_grad=True)
# Epoch [446/500], Loss: 0.0037
# total loss: 0.003731152042746544
# Parameter containing:
# tensor([[ 0.8812, -0.8775]], requires_grad=True)
# Epoch [447/500], Loss: 0.0037
# total loss: 0.0037289776373654604
# Parameter containing:
# tensor([[ 0.8817, -0.8779]], requires_grad=True)
# Epoch [448/500], Loss: 0.0037
# total loss: 0.0037268076557666063
# Parameter containing:
# tensor([[ 0.8821, -0.8784]], requires_grad=True)
# Epoch [449/500], Loss: 0.0037
# total loss: 0.0037246481515467167
# Parameter containing:
# tensor([[ 0.8826, -0.8789]], requires_grad=True)
# Epoch [450/500], Loss: 0.0037
# total loss: 0.003722485387697816
# Parameter containing:
# tensor([[ 0.8831, -0.8793]], requires_grad=True)
# Epoch [451/500], Loss: 0.0037
# total loss: 0.0037203298415988684
# Parameter containing:
# tensor([[ 0.8835, -0.8798]], requires_grad=True)
# Epoch [452/500], Loss: 0.0037
# total loss: 0.003718181047588587
# Parameter containing:
# tensor([[ 0.8840, -0.8803]], requires_grad=True)
# Epoch [453/500], Loss: 0.0037
# total loss: 0.0037160359788686037
# Parameter containing:
# tensor([[ 0.8845, -0.8807]], requires_grad=True)
# Epoch [454/500], Loss: 0.0037
# total loss: 0.0037138971965759993
# Parameter containing:
# tensor([[ 0.8849, -0.8812]], requires_grad=True)
# Epoch [455/500], Loss: 0.0037
# total loss: 0.0037117598112672567
# Parameter containing:
# tensor([[ 0.8854, -0.8816]], requires_grad=True)
# Epoch [456/500], Loss: 0.0037
# total loss: 0.0037096303422003984
# Parameter containing:
# tensor([[ 0.8859, -0.8821]], requires_grad=True)
# Epoch [457/500], Loss: 0.0037
# total loss: 0.003707501571625471
# Parameter containing:
# tensor([[ 0.8863, -0.8826]], requires_grad=True)
# Epoch [458/500], Loss: 0.0037
# total loss: 0.0037053783889859915
# Parameter containing:
# tensor([[ 0.8868, -0.8830]], requires_grad=True)
# Epoch [459/500], Loss: 0.0037
# total loss: 0.003703265218064189
# Parameter containing:
# tensor([[ 0.8873, -0.8835]], requires_grad=True)
# Epoch [460/500], Loss: 0.0037
# total loss: 0.0037011494860053062
# Parameter containing:
# tensor([[ 0.8877, -0.8840]], requires_grad=True)
# Epoch [461/500], Loss: 0.0037
# total loss: 0.003699044231325388
# Parameter containing:
# tensor([[ 0.8882, -0.8844]], requires_grad=True)
# Epoch [462/500], Loss: 0.0037
# total loss: 0.0036969406064599752
# Parameter containing:
# tensor([[ 0.8887, -0.8849]], requires_grad=True)
# Epoch [463/500], Loss: 0.0037
# total loss: 0.0036948425695300102
# Parameter containing:
# tensor([[ 0.8891, -0.8853]], requires_grad=True)
# Epoch [464/500], Loss: 0.0037
# total loss: 0.0036927484907209873
# Parameter containing:
# tensor([[ 0.8896, -0.8858]], requires_grad=True)
# Epoch [465/500], Loss: 0.0037
# total loss: 0.0036906579043716192
# Parameter containing:
# tensor([[ 0.8900, -0.8862]], requires_grad=True)
# Epoch [466/500], Loss: 0.0037
# total loss: 0.0036885724402964115
# Parameter containing:
# tensor([[ 0.8905, -0.8867]], requires_grad=True)
# Epoch [467/500], Loss: 0.0037
# total loss: 0.0036864951252937317
# Parameter containing:
# tensor([[ 0.8910, -0.8872]], requires_grad=True)
# Epoch [468/500], Loss: 0.0037
# total loss: 0.0036844161804765463
# Parameter containing:
# tensor([[ 0.8914, -0.8876]], requires_grad=True)
# Epoch [469/500], Loss: 0.0037
# total loss: 0.003682346548885107
# Parameter containing:
# tensor([[ 0.8919, -0.8881]], requires_grad=True)
# Epoch [470/500], Loss: 0.0037
# total loss: 0.0036802785471081734
# Parameter containing:
# tensor([[ 0.8923, -0.8885]], requires_grad=True)
# Epoch [471/500], Loss: 0.0037
# total loss: 0.0036782165989279747
# Parameter containing:
# tensor([[ 0.8928, -0.8890]], requires_grad=True)
# Epoch [472/500], Loss: 0.0037
# total loss: 0.003676157910376787
# Parameter containing:
# tensor([[ 0.8932, -0.8894]], requires_grad=True)
# Epoch [473/500], Loss: 0.0037
# total loss: 0.0036741041112691164
# Parameter containing:
# tensor([[ 0.8937, -0.8899]], requires_grad=True)
# Epoch [474/500], Loss: 0.0037
# total loss: 0.0036720559000968933
# Parameter containing:
# tensor([[ 0.8942, -0.8903]], requires_grad=True)
# Epoch [475/500], Loss: 0.0037
# total loss: 0.0036700081545859575
# Parameter containing:
# tensor([[ 0.8946, -0.8908]], requires_grad=True)
# Epoch [476/500], Loss: 0.0037
# total loss: 0.003667968325316906
# Parameter containing:
# tensor([[ 0.8951, -0.8913]], requires_grad=True)
# Epoch [477/500], Loss: 0.0037
# total loss: 0.003665930824354291
# Parameter containing:
# tensor([[ 0.8955, -0.8917]], requires_grad=True)
# Epoch [478/500], Loss: 0.0037
# total loss: 0.0036639005411416292
# Parameter containing:
# tensor([[ 0.8960, -0.8922]], requires_grad=True)
# Epoch [479/500], Loss: 0.0037
# total loss: 0.0036618737503886223
# Parameter containing:
# tensor([[ 0.8964, -0.8926]], requires_grad=True)
# Epoch [480/500], Loss: 0.0037
# total loss: 0.003659849753603339
# Parameter containing:
# tensor([[ 0.8969, -0.8931]], requires_grad=True)
# Epoch [481/500], Loss: 0.0037
# total loss: 0.0036578294821083546
# Parameter containing:
# tensor([[ 0.8973, -0.8935]], requires_grad=True)
# Epoch [482/500], Loss: 0.0037
# total loss: 0.0036558147985488176
# Parameter containing:
# tensor([[ 0.8978, -0.8940]], requires_grad=True)
# Epoch [483/500], Loss: 0.0037
# total loss: 0.003653803840279579
# Parameter containing:
# tensor([[ 0.8982, -0.8944]], requires_grad=True)
# Epoch [484/500], Loss: 0.0037
# total loss: 0.0036517975386232138
# Parameter containing:
# tensor([[ 0.8987, -0.8949]], requires_grad=True)
# Epoch [485/500], Loss: 0.0037
# total loss: 0.003649796824902296
# Parameter containing:
# tensor([[ 0.8991, -0.8953]], requires_grad=True)
# Epoch [486/500], Loss: 0.0036
# total loss: 0.0036477979738265276
# Parameter containing:
# tensor([[ 0.8996, -0.8957]], requires_grad=True)
# Epoch [487/500], Loss: 0.0036
# total loss: 0.003645804477855563
# Parameter containing:
# tensor([[ 0.9000, -0.8962]], requires_grad=True)
# Epoch [488/500], Loss: 0.0036
# total loss: 0.0036438133101910353
# Parameter containing:
# tensor([[ 0.9005, -0.8966]], requires_grad=True)
# Epoch [489/500], Loss: 0.0036
# total loss: 0.0036418274976313114
# Parameter containing:
# tensor([[ 0.9009, -0.8971]], requires_grad=True)
# Epoch [490/500], Loss: 0.0036
# total loss: 0.0036398442462086678
# Parameter containing:
# tensor([[ 0.9014, -0.8975]], requires_grad=True)
# Epoch [491/500], Loss: 0.0036
# total loss: 0.003637870540842414
# Parameter containing:
# tensor([[ 0.9018, -0.8980]], requires_grad=True)
# Epoch [492/500], Loss: 0.0036
# total loss: 0.0036358952056616545
# Parameter containing:
# tensor([[ 0.9023, -0.8984]], requires_grad=True)
# Epoch [493/500], Loss: 0.0036
# total loss: 0.0036339261569082737
# Parameter containing:
# tensor([[ 0.9027, -0.8989]], requires_grad=True)
# Epoch [494/500], Loss: 0.0036
# total loss: 0.0036319619975984097
# Parameter containing:
# tensor([[ 0.9032, -0.8993]], requires_grad=True)
# Epoch [495/500], Loss: 0.0036
# total loss: 0.003630000166594982
# Parameter containing:
# tensor([[ 0.9036, -0.8998]], requires_grad=True)
# Epoch [496/500], Loss: 0.0036
# total loss: 0.003628042759373784
# Parameter containing:
# tensor([[ 0.9041, -0.9002]], requires_grad=True)
# Epoch [497/500], Loss: 0.0036
# total loss: 0.003626087214797735
# Parameter containing:
# tensor([[ 0.9045, -0.9006]], requires_grad=True)
# Epoch [498/500], Loss: 0.0036
# total loss: 0.0036241398192942142
# Parameter containing:
# tensor([[ 0.9049, -0.9011]], requires_grad=True)
# Epoch [499/500], Loss: 0.0036
# total loss: 0.003622194053605199
# Parameter containing:
# tensor([[ 0.9054, -0.9015]], requires_grad=True)
# Epoch [500/500], Loss: 0.0036

# %%
def test_model(model, new_data, expected_result):
    test_input = torch.tensor(new_data, dtype=torch.float32)
    test_output = trained_model(test_input)

    # apply the step function with the step at 0.5 to decide whether to predict 1 or 0 for this element
    predicted_classes = torch.tensor(test_output + 0.5, dtype=torch.int)
    test_output_compare = torch.tensor(expected_result, dtype=torch.float32)

    diff = abs(predicted_classes - test_output_compare)
    accuracy = 1 - (int(sum(diff)) / len(test_input))
    return accuracy

# %%
test_input = np.random.randint(1, 100, size=(500, 2))
test_output_compare = []

for i in test_input:
    test_output_compare.append([int(i[0] >= i[1])])

test_model(trained_model, test_input, test_output_compare)

# %%
for i, param in trained_model.named_parameters():
    print(i)
    print(param)
# Out:
# fc.weight
# Parameter containing:
# tensor([[ 0.9054, -0.9015]], requires_grad=True)
