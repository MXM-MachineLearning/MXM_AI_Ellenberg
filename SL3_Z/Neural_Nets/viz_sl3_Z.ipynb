# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("matrices_train.csv")
df
# Out:
#              00        01        02        10        11        12        20  \
# 0        109421   -509177   -157640    379835  -1767492   -547205   -218490
# 1           -11        -5        -2        -6        -2        -1        72
# 2             1        -2         0      -526        27       -78      2679
# 3           437       555      1181      1244      1577      3357     -5523
# 4     -20379797 -23052926 -50290573 -24460562 -27668947 -60360546  20413785
# ...         ...       ...       ...       ...       ...       ...       ...
# 29995       839      -498       783      2812     -1726      2591     -1629
# 29996        37        14        56        42        19        67       -36
# 29997    379101  -1051883   -207069   1077176  -2988816   -588365  -4780575
# 29998   3077834   2945712   6602353   8745952   8370515  18761201  -5888961
# 29999      9414    -28829     -5616     26207    -80257    -15635   -115893
#
#              21        22  last
# 0       1016706    314767     1
# 1            33        13     0
# 2          -141       397     0
# 3         -6999    -14900     0
# 4      23091372  50374444     1
# ...         ...       ...   ...
# 29995       993     -1505     1
# 29996       -15       -56     1
# 29997  13264554   2611201     0
# 29998  -5636166 -12632585     1
# 29999    354915     69142     0
#
# [30000 rows x 10 columns]

# %%
# trying pca 
matrix = ['00','01','02','10','11','12','20','21','22']
x = df.loc[:, matrix].values
y = df.loc[:,['last']].values
x = StandardScaler().fit_transform(x)

#CHAT GPT

pca = PCA(n_components=3)
fittedData = pca.fit_transform(x)

# Create a 3D scatter plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(fittedData[:, 0], fittedData[:, 1], fittedData[:, 2], c=y)

# Set labels for each axis
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')

# Set the plot title
ax.set_title('3D PCA Plot')

# Show the plot
plt.show()

# %%
plt.scatter(fittedData[:, 0], fittedData[:, 1], c=y)
plt.show()
